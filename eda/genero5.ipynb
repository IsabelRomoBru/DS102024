# %%
import pandas as pd
import numpy as np

# %%
g=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/eda/ea0010587-brecha-salarial-de-genero-no-ajustada-a-las-caracteristicas-individuales-en-salario-por-hora-por-tipo-de-jornada-y-periodo-espana-anual-nacional-mujeres-y-hombres-en-espana-identificador-api-108911.csv')

# %%
pd.set_option('display.max_colwidth',None)
g
# Out:
#                                                                   URL  \
# 0  https://datos.gob.es/catalogo/80d9fd1a-df50-4ef9-b714-cd41e31bd3cc
#
#                    IDENTIFICADOR  \
# 0  urn:ine:es:TABLA:T3:452:10891
#
#                                                                                                                                                                                                                                                                                                                                  TÍTULO  \
# 0  [en]Gender salary breech (not adjusted to individual characteristics) by salary by hour by type of working day and period Spain. MYH (API identifier: 10891)[es]Brecha salarial de género (no ajustada a las características individuales) en salario por hora por tipo de jornada y periodo. España. MYH (Identificador API: 10891)
#
# ...

# %%
g2=pd.read_json('https://servicios.ine.es/wstempus/jsCache/es/DATOS_TABLA/10891?tip=AM')

# %%
g2
# Out:
#        COD                                             Nombre   T3_Unidad  \
# 0  MYH9027  Jornada a tiempo completo. Eurostat. Total Nac...  Porcentaje
# 1  MYH9026  Jornada a tiempo parcial. Eurostat. Total Naci...  Porcentaje
#
#   T3_Escala                                           MetaData  \
# 0            [{'Id': 10758, 'T3_Variable': 'Tipo de jornada...
# 1            [{'Id': 10759, 'T3_Variable': 'Tipo de jornada...
#
#                                                 Data
# 0  [{'Fecha': '2021-01-01T00:00:00.000+01:00', 'T...
# 1  [{'Fecha': '2021-01-01T00:00:00.000+01:00', 'T...

# %%
g4=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/eda/10891.csv')

# %%
g4
# Out:
#                                              Tipo de jornada\tTotal Nacional\tPeriodo\tTotal
# Jornada a tiempo completo\tEspaña\t2021\t2                                               5.0
# Jornada a tiempo completo\tEspaña\t2020\t2                                               5.0
# Jornada a tiempo completo\tEspaña\t2019\t3                                               4.0
# Jornada a tiempo completo\tEspaña\t2018\t6                                               5.0
# Jornada a tiempo completo\tEspaña\t2017\t8                                               NaN
# Jornada a tiempo completo\tEspaña\t2016\t10                                              6.0
# Jornada a tiempo completo\tEspaña\t2015\t10                                              2.0
# Jornada a tiempo completo\tEspaña\t2014\t9                                               6.0
# Jornada a tiempo completo\tEspaña\t2013\t13                                              4.0
# ...
