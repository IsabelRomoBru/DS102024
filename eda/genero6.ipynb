# %%
import pandas as pd
import numpy as np

# %%
g=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/eda/OECD.ELS.SAE,DSD_EARNINGS@GENDER_WAGE_GAP,1.0+......_T.csv')

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1863 entries, 0 to 1862
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   STRUCTURE              1863 non-null   object
#  1   STRUCTURE_ID           1863 non-null   object
#  2   STRUCTURE_NAME         0 non-null      float64
#  3   ACTION                 1863 non-null   object
#  4   REF_AREA               1863 non-null   object
#  5   Unnamed: 5             0 non-null      float64
#  6   MEASURE                1863 non-null   object
#  7   Unnamed: 7             0 non-null      float64
#  8   UNIT_MEASURE           1863 non-null   object
#  9   Unnamed: 9             0 non-null      float64
#  10  PAY_PERIOD             1863 non-null   object
#  11  Unnamed: 11            0 non-null      float64
#  12  PRICE_BASE             1863 non-null   object
#  13  Unnamed: 13            0 non-null      float64
# ...

# %%
g.head(30)
# Out:
#    STRUCTURE                                    STRUCTURE_ID  STRUCTURE_NAME  \
# 0   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 1   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 2   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 3   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 4   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 5   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 6   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 7   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 8   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 9   DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# 10  DATAFLOW  OECD.ELS.SAE:DSD_EARNINGS@GENDER_WAGE_GAP(1.0)             NaN
# ...

# %%
g.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Unnamed: 5', 'MEASURE', 'Unnamed: 7', 'UNIT_MEASURE', 'Unnamed: 9',
#        'PAY_PERIOD', 'Unnamed: 11', 'PRICE_BASE', 'Unnamed: 13',
#        'AGGREGATION_OPERATION', 'Unnamed: 15', 'SEX', 'Unnamed: 17',
#        'TIME_PERIOD', 'Unnamed: 19', 'OBS_VALUE', 'Unnamed: 21', 'BASE_PER',
#        'Unnamed: 23', 'OBS_STATUS', 'Unnamed: 25', 'UNIT_MULT', 'Unnamed: 27',
#        'DECIMALS', 'Unnamed: 29'],
#       dtype='object')
