# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/6114458/10052245/profile_killers.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20241215%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241215T184357Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')

# %%
df
# Out:
#                                      Name  \
# 0                           Luis Garavito
# 1                             Pedro López
# 2                             Javed Iqbal
# 3                          Mikhail Popkov
# 4                  Daniel Camargo Barbosa
# ..                                    ...
# 706                         Paul Bernardo
# 707  Michael Bear Carson and Suzan Carson
# 708          Joseph and Michael Kallinger
# 709                     Silvia Merez Cult
# 710                       Raya and Sakina
#
#                                                   Born  \
# 0    Luis Alfredo Garavito Cubillos(1957-01-25)25 J...
# 1    Pedro Alonso López (1948-10-08) 8 October 1948...
# 2    Javed Iqbal Mughal1961[1][a]Lahore, Punjab, Pa...
# 3    Mikhail Viktorovich Popkov (1964-03-07) 7 Marc...
# 4    Daniel Camargo Barbosa(1930-01-22)22 January 1...
# ..                                                 ...
# 706  Paul Kenneth Bernardo (1964-08-27) August 27, ...
# ...

# %%
df.describe()
# Out:
#                    Name     Born     Died Cause of death Nicknames   Motive  \
# count               711      711      711            711       711      711
# unique              711      671      398              2       467       46
# top     Raya and Sakina  Unknown  Unknown        Unknown   Unknown  Unknown
# freq                  1       41      314            710       243      654
#
#        Conviction Criminal Penalty Criminal Status  Victims Span of Crimes  \
# count         711              711             711      711            711
# unique        296                1               1      357            554
# top       Unknown          Unknown         Unknown  Unknown        Unknown
# freq          209              711             711       41             81
#
#               Country State(s) Date Apprehended
# count             711      711              705
# unique            126      302              525
# top     United States  Unknown          Unknown
# ...

# %%
df.isna().sum()
# Out:
# Name                0
# Born                0
# Died                0
# Cause of death      0
# Nicknames           0
# Motive              0
# Conviction          0
# Criminal Penalty    0
# Criminal Status     0
# Victims             0
# Span of Crimes      0
# Country             0
# State(s)            0
# Date Apprehended    6
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Born', 'Died', 'Cause of death', 'Nicknames', 'Motive',
#        'Conviction', 'Criminal Penalty', 'Criminal Status', 'Victims',
#        'Span of Crimes', 'Country', 'State(s)', 'Date Apprehended'],
#       dtype='object')

# %%
df.shape
# Out:
# (711, 14)

# %%
df.head(20)
# Out:
#                        Name  \
# 0             Luis Garavito
# 1               Pedro López
# 2               Javed Iqbal
# 3            Mikhail Popkov
# 4    Daniel Camargo Barbosa
# 5     Pedro Rodrigues Filho
# 6     Kampatimar Shankariya
# 7             Hoshang Amini
# 8               Yang Xinhai
# 9               Abul Djabar
# 10            Samuel Little
# 11             William Unek
# 12           Mohammed Bijeh
# 13         Andrei Chikatilo
# 14       Anatoly Onoprienko
# 15  Florisvaldo de Oliveira
# 16             Gary Ridgway
# 17     Alexander Pichushkin
# 18               Wang Qiang
# 19            Ahmad Suradji
#
#                                                  Born  \
# 0   Luis Alfredo Garavito Cubillos(1957-01-25)25 J...
# 1   Pedro Alonso López (1948-10-08) 8 October 1948...
# 2   Javed Iqbal Mughal1961[1][a]Lahore, Punjab, Pa...
# 3   Mikhail Viktorovich Popkov (1964-03-07) 7 Marc...
# 4   Daniel Camargo Barbosa(1930-01-22)22 January 1...
# ...
