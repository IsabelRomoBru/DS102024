# %%
import numpy as np
import pandas as pd

# %%
g=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/eda/EDA_datos_ILOSTAT/datospobrezap.csv')

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ref_area.label   472 non-null    object
#  1   source.label     472 non-null    object
#  2   indicator.label  472 non-null    object
#  3   sex.label        472 non-null    object
#  4   classif1.label   472 non-null    object
#  5   time             472 non-null    int64
#  6   obs_value        472 non-null    float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 25.9+ KB

# %%
g.describe()
# Out:
#               time   obs_value
# count   472.000000  472.000000
# mean   2016.966102    0.376521
# std       2.279540    0.650590
# min    2014.000000    0.004000
# 25%    2015.000000    0.025000
# 50%    2017.000000    0.106500
# 75%    2018.000000    0.319250
# max    2024.000000    2.969000

# %%
g.head(20)
# Out:
#              ref_area.label              source.label  \
# 0   Europe and Central Asia  ILO - Modelled Estimates
# 1   Europe and Central Asia  ILO - Modelled Estimates
# 2   Europe and Central Asia  ILO - Modelled Estimates
# 3   Europe and Central Asia  ILO - Modelled Estimates
# 4   Europe and Central Asia  ILO - Modelled Estimates
# 5   Europe and Central Asia  ILO - Modelled Estimates
# 6   Europe and Central Asia  ILO - Modelled Estimates
# 7   Europe and Central Asia  ILO - Modelled Estimates
# 8   Europe and Central Asia  ILO - Modelled Estimates
# 9   Europe and Central Asia  ILO - Modelled Estimates
# 10  Europe and Central Asia  ILO - Modelled Estimates
# 11  Europe and Central Asia  ILO - Modelled Estimates
# 12  Europe and Central Asia  ILO - Modelled Estimates
# 13  Europe and Central Asia  ILO - Modelled Estimates
# 14  Europe and Central Asia  ILO - Modelled Estimates
# 15  Europe and Central Asia  ILO - Modelled Estimates
# ...

# %%
g.shape
# Out:
# (472, 7)

# %%
g.isna().sum()
# Out:
# ref_area.label     0
# source.label       0
# indicator.label    0
# sex.label          0
# classif1.label     0
# time               0
# obs_value          0
# dtype: int64

# %%
g1=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/eda/EDA_datos_ILOSTAT/mujeresenaltoscargos.csv')

# %%
g1.shape
# Out:
# (154, 9)

# %%
g1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ref_area.label        154 non-null    object
#  1   source.label          154 non-null    object
#  2   indicator.label       154 non-null    object
#  3   time                  154 non-null    int64
#  4   obs_value             154 non-null    float64
#  5   obs_status.label      0 non-null      float64
#  6   note_classif.label    0 non-null      float64
#  7   note_indicator.label  0 non-null      float64
#  8   note_source.label     0 non-null      float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 11.0+ KB

# %%
g1.head()
# Out:
#             ref_area.label              source.label  \
# 0  Europe and Central Asia  ILO - Modelled Estimates
# 1  Europe and Central Asia  ILO - Modelled Estimates
# 2  Europe and Central Asia  ILO - Modelled Estimates
# 3  Europe and Central Asia  ILO - Modelled Estimates
# 4  Europe and Central Asia  ILO - Modelled Estimates
#
#                                      indicator.label  time  obs_value  \
# 0  SDG indicator 5.5.2 - Proportion of women in m...  2023     36.004
# 1  SDG indicator 5.5.2 - Proportion of women in m...  2022     35.600
# 2  SDG indicator 5.5.2 - Proportion of women in m...  2021     36.609
# 3  SDG indicator 5.5.2 - Proportion of women in m...  2020     35.966
# 4  SDG indicator 5.5.2 - Proportion of women in m...  2019     35.357
#
#    obs_status.label  note_classif.label  note_indicator.label  \
# 0               NaN                 NaN                   NaN
# 1               NaN                 NaN                   NaN
# ...

# %%
g1.isna().sum()
# Out:
# ref_area.label            0
# source.label              0
# indicator.label           0
# time                      0
# obs_value                 0
# obs_status.label        154
# note_classif.label      154
# note_indicator.label    154
# note_source.label       154
# dtype: int64

# %%
g3=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/eda/EDA_datos_ILOSTAT/empleoporsexo.csv')

# %%
g3.head(20)
# Out:
#              ref_area.label              source.label  \
# 0   Europe and Central Asia  ILO - Modelled Estimates
# 1   Europe and Central Asia  ILO - Modelled Estimates
# 2   Europe and Central Asia  ILO - Modelled Estimates
# 3   Europe and Central Asia  ILO - Modelled Estimates
# 4   Europe and Central Asia  ILO - Modelled Estimates
# 5   Europe and Central Asia  ILO - Modelled Estimates
# 6   Europe and Central Asia  ILO - Modelled Estimates
# 7   Europe and Central Asia  ILO - Modelled Estimates
# 8   Europe and Central Asia  ILO - Modelled Estimates
# 9   Europe and Central Asia  ILO - Modelled Estimates
# 10  Europe and Central Asia  ILO - Modelled Estimates
# 11  Europe and Central Asia  ILO - Modelled Estimates
# 12  Europe and Central Asia  ILO - Modelled Estimates
# 13  Europe and Central Asia  ILO - Modelled Estimates
# 14  Europe and Central Asia  ILO - Modelled Estimates
# 15  Europe and Central Asia  ILO - Modelled Estimates
# ...

# %%
g3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2360 entries, 0 to 2359
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ref_area.label    2360 non-null   object
#  1   source.label      2360 non-null   object
#  2   indicator.label   2360 non-null   object
#  3   sex.label         2360 non-null   object
#  4   classif1.label    2360 non-null   object
#  5   classif2.label    2360 non-null   object
#  6   time              2360 non-null   int64
#  7   obs_value         2360 non-null   float64
#  8   obs_status.label  0 non-null      float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 166.1+ KB

# %%
g3.describe()
# Out:
#               time      obs_value  obs_status.label
# count  2360.000000    2360.000000               0.0
# mean   2016.966102   24685.025915               NaN
# std       2.277606   61993.499884               NaN
# min    2014.000000       0.482000               NaN
# 25%    2015.000000      43.485500               NaN
# 50%    2017.000000    1181.255500               NaN
# 75%    2018.000000   13308.908750               NaN
# max    2024.000000  427662.408000               NaN

# %%
g3.isna().sum()
# Out:
# ref_area.label         0
# source.label           0
# indicator.label        0
# sex.label              0
# classif1.label         0
# classif2.label         0
# time                   0
# obs_value              0
# obs_status.label    2360
# dtype: int64

# %%
g3.shape
# Out:
# (2360, 9)

# %%
g4=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/eda/EDA_datos_ILOSTAT/gananciasporsexo.csv')

# %%
g4.shape
# Out:
# (9183, 11)

# %%
g4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9183 entries, 0 to 9182
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ref_area.label        9183 non-null   object
#  1   source.label          9183 non-null   object
#  2   indicator.label       9183 non-null   object
#  3   sex.label             9183 non-null   object
#  4   classif1.label        9183 non-null   object
#  5   time                  9183 non-null   int64
#  6   obs_value             9090 non-null   float64
#  7   obs_status.label      603 non-null    object
#  8   note_classif.label    0 non-null      float64
#  9   note_indicator.label  9183 non-null   object
#  10  note_source.label     9132 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 789.3+ KB

# %%
g4.isnull().sum()
# Out:
# ref_area.label             0
# source.label               0
# indicator.label            0
# sex.label                  0
# classif1.label             0
# time                       0
# obs_value                 93
# obs_status.label        8580
# note_classif.label      9183
# note_indicator.label       0
# note_source.label         51
# dtype: int64

# %%
g4.describe()
# Out:
#               time     obs_value  note_classif.label
# count  9183.000000   9090.000000                 0.0
# mean   2017.471088    316.845934                 NaN
# std       2.833584   1320.672640                 NaN
# min    2013.000000      0.000000                 NaN
# 25%    2015.000000      8.652500                 NaN
# 50%    2018.000000     17.000000                 NaN
# 75%    2020.000000     65.000000                 NaN
# max    2023.000000  19285.000000                 NaN

# %%
g4.head(20)
# Out:
#    ref_area.label                       source.label  \
# 0         Albania  ES - Structure of Earnings Survey
# 1         Albania  ES - Structure of Earnings Survey
# 2         Albania  ES - Structure of Earnings Survey
# 3         Albania  ES - Structure of Earnings Survey
# 4         Albania  ES - Structure of Earnings Survey
# 5         Albania  ES - Structure of Earnings Survey
# 6         Albania  ES - Structure of Earnings Survey
# 7         Albania  ES - Structure of Earnings Survey
# 8         Albania  ES - Structure of Earnings Survey
# 9         Albania  ES - Structure of Earnings Survey
# 10        Albania  ES - Structure of Earnings Survey
# 11        Albania  ES - Structure of Earnings Survey
# 12        Albania  ES - Structure of Earnings Survey
# 13        Albania  ES - Structure of Earnings Survey
# 14        Albania  ES - Structure of Earnings Survey
# 15        Albania  ES - Structure of Earnings Survey
# 16        Albania  ES - Structure of Earnings Survey
# ...
