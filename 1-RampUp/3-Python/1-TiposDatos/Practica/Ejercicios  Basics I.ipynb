# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
calle= "cavanilles"
callenum= 43
ciudad= "Madrid"
codigopostal= 28007
dirección= (calle, callenum, ciudad, codigopostal)
print(dirección)
# Out:
# ('cavanilles', 43, 'Madrid', 28007)

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
str(callenum)
str(codigopostal)
print( calle, callenum, ciudad, codigopostal)
# Out:
# cavanilles 43 Madrid 28007

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %% [markdown]
# 1. Ok
# 2. Falta cerrar con comillas
# 3. No puedes utilizar palabras reservadas como True
# 4. No podemos poner espacios en el nombre de la variable
# 5. No puedes utilizar palabras reservadas como import
# 6. No se puede iniciar variable con número al principio
# 7. Ok

# %% [markdown]
# **1 esta bien
# **2 falta "
# **3 palabra reservada
# **4 espacio
# **5 palabra reservada
# **6no puede empezar en mayusuculas
# **7 esta bien

# %%
mi_variable = "Economía"
print(mi_variable)
otra_var = "Ejercicio
print(otra_var)
True = "Ejercicio"
print(True)
mi variab1e = "Alpha"
print(mi variable)
import = 40
print(import)
81mi_variable = "Agua"
print(81mi_variable)
mi_variable10 = 6
print(mi_variable10)
# Out:
#   Cell In[7], line 3
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
grados= float(input("introduce los grados"))
conversión= grados* (9/5)+32
print(f"la conversión de {grados} grados celsius es {conversión} grados fahrenheit")
# Out:
# la conversión de 23.0 grados celsius es 73.4 grados fahrenheit

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
#se crea una variable de grados celsius mediante un input para que el usurario sea capaz de elegir los grados

""" se crea otra variable de conversión con los grados seleccionados y la operación de conversión
finalmente se crea un print donde refleje con una conclusión la conversión de los grados
"""
# Out:
# ' se crea otra variable de conversión con los grados seleccionados y la operación de conversión\nfinalmente se crea un print donde refleje con una conclusión la conversión de los grados\n'
