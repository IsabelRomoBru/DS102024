# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las dos primeras variables creadas

# %%
entero= 4
print (type(entero))
decimal= 8.9
print (type(decimal))
suma= entero+decimal
print(suma)
print (type(suma)) #el resultado es un float
del(entero,decimal,suma)
# Out:
# <class 'int'>
# <class 'float'>
# 12.9
# <class 'float'>

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
import math
grados= float(input("Introduce los grados"))
radianes= grados*(math.pi/180)
print(f"{grados} grados son {radianes} radianes")
# Out:
# 8.0 grados son 0.13962634015954636 radianes

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
import math
base= float(input("introducir valor base"))
altura= float(input("introducir valor altura"))
area= base* altura
print(f"el valor del area es {area}")
# Out:
# el valor del area es 170.0

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1
A == B
A != C
A > C
C <= A
B != C
# Out:
# True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
input1= input("escriba un valor")
input2= input("escriba el segundo valor")
if input1 == input2:
    print("Los valores son iguales")
else:
    print("Los valores son distintos")
# Out:
# Los valores son distintos

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
input1= input("escriba un valor")
input2= input("escriba el segundo valor")
input3= input("escriba el tercer valor")
if input1 == input2== input3:
    print("Los valores son iguales")
elif input1==input2 or input1== input3 or input2==input3:
    print(" al menos dos son iguales")
else:
    print("ninguno son iguales")
# Out:
#  al menos dos son iguales

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
input_1= float(input("introduce un número"))
input_2= float(input("introduce un segundo número"))
if input_1+input_2 > 10:
    print("resultado mayor que 10")
elif input_1+input_2 == 10:
    print("El resultado es igual a 10")
else:
    print("suma menor que 10")
# Out:
# El resultado es igual a 10

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %% [markdown]
# 1. False
# 2. False
# 3. False
# 4. False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista= {4,5,8, -1}
print (max (lista))
print (sum (lista))
decimal= 63.451256965
print (round(decimal, 3))
# Out:
# 8
# 16
# 63.451

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "A quien madruga, dios le ayuda"
#
# 1. Pasarlo todo a mayusculas
# 2. Pasarlo todo a minusculas
# 3. Pasar a mayusculas solo las iniciales de las palabras
# 4. Crea una lista dividiendolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minusculas

# %%
texto= "A quien madrugra, dios le ayuda"
print (texto.upper())
print (texto.lower())
print (texto. title())
lista= ["A quien madruga, dios le ayuda"]
print (texto.replace (",", "."))
print(texto.replace("a", ""))
# Out:
# A QUIEN MADRUGRA, DIOS LE AYUDA
# a quien madrugra, dios le ayuda
# A Quien Madrugra, Dios Le Ayuda
# A quien madrugra. dios le ayuda
# A quien mdrugr, dios le yud

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
lista1= [3,7,9]
print(lista1)
lista1.append (6)
print (lista1)
print (sum(lista1))
print( lista1.pop (2))
print(lista1)
lista1.insert(3, 5)
print (lista1)
lista2= [8,9.3, 2, 7]
print(lista1+lista2)
# Out:
# [3, 7, 9]
# [3, 7, 9, 6]
# 25
# 9
# [3, 7, 6]
# [3, 7, 6, 5]
# [3, 7, 6, 5, 8, 9.3, 2, 7]
