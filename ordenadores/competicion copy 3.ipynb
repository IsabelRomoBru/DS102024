# %% [markdown]
# ### Librerias

# %%
import pandas as pd

import urllib.request
from PIL import Image
import re

# %% [markdown]
# ## Data

# %%
df=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/ordenadores/train.csv')

# %% [markdown]
# ## Data exploración

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         912 non-null    int64
#  1   Company           912 non-null    object
#  2   Product           912 non-null    object
#  3   TypeName          912 non-null    object
#  4   Inches            912 non-null    float64
#  5   ScreenResolution  912 non-null    object
#  6   Cpu               912 non-null    object
#  7   Ram               912 non-null    object
#  8   Memory            912 non-null    object
#  9   Gpu               912 non-null    object
#  10  OpSys             912 non-null    object
#  11  Weight            912 non-null    object
#  12  Price_euros       912 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 92.8+ KB

# %%
df.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0       1223    Dell       Inspiron 5567            Notebook    15.6
# 1         78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2       1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3        161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4        922      LG         Gram 14Z970           Ultrabook    14.0
#
#                             ScreenResolution                         Cpu  Ram  \
# 0                          Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
# 1                          Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
# 2           Quad HD+ / Touchscreen 3200x1800   Intel Core i5 7Y54 1.2GHz  8GB
# 3            Full HD / Touchscreen 1920x1080  Intel Core i7 8550U 1.8GHz  8GB
# 4  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz  8GB
#
#       Memory                     Gpu       OpSys  Weight  Price_euros
# 0  256GB SSD      AMD Radeon R7 M445  Windows 10  2.36kg        889.0
# 1    2TB HDD   Intel HD Graphics 620       No OS   2.2kg        519.0
# 2  256GB SSD   Intel HD Graphics 615  Windows 10  1.24kg       1813.0
# 3  256GB SSD  Intel UHD Graphics 620  Windows 10  1.56kg       1049.0
# 4  512GB SSD   Intel HD Graphics 620  Windows 10  0.98kg       1899.0

# %% [markdown]
# ## Data processing

# %%
df
# Out:
#      laptop_ID Company             Product            TypeName  Inches  \
# 0         1223    Dell       Inspiron 5567            Notebook    15.6
# 1           78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2         1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3          161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4          922      LG         Gram 14Z970           Ultrabook    14.0
# ..         ...     ...                 ...                 ...     ...
# 907        709  Lenovo   IdeaPad 320-15AST            Notebook    15.6
# 908        947  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3
# 909        590    Dell       Latitude 5580            Notebook    15.6
# 910       1143  Lenovo  Legion Y520-15IKBN              Gaming    15.6
# 911        531    Dell       Inspiron 5770            Notebook    17.3
#
#                                ScreenResolution                          Cpu  \
# 0                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 2              Quad HD+ / Touchscreen 3200x1800    Intel Core i5 7Y54 1.2GHz
# 3               Full HD / Touchscreen 1920x1080   Intel Core i7 8550U 1.8GHz
# 4     IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# ..                                          ...                          ...
# 907                           Full HD 1920x1080    AMD A9-Series 9420 2.9GHz
# 908  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6560U 2.2GHz
# 909                           Full HD 1920x1080   Intel Core i7 7600U 2.8GHz
# 910                 IPS Panel Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 911                 IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 0     8GB             256GB SSD       AMD Radeon R7 M445  Windows 10  2.36kg
# 1     8GB               2TB HDD    Intel HD Graphics 620       No OS   2.2kg
# 2     8GB             256GB SSD    Intel HD Graphics 615  Windows 10  1.24kg
# 3     8GB             256GB SSD   Intel UHD Graphics 620  Windows 10  1.56kg
# 4     8GB             512GB SSD    Intel HD Graphics 620  Windows 10  0.98kg
# ..    ...                   ...                      ...         ...     ...
# 907   4GB             256GB SSD           AMD Radeon 530  Windows 10   2.2kg
# 908  16GB               1TB SSD  Intel Iris Graphics 540  Windows 10   1.3kg
# 909  16GB             256GB SSD     Nvidia GeForce 930MX  Windows 10  1.93kg
# 910   8GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060       No OS   2.4kg
# 911   8GB  128GB SSD +  1TB HDD           AMD Radeon 530       Linux   2.8kg
#
#      Price_euros
# 0         889.00
# 1         519.00
# 2        1813.00
# 3        1049.00
# 4        1899.00
# ..           ...
# 907       399.00
# 908      1799.00
# 909      1537.39
# 910       989.00
# 911       889.00
#
# [912 rows x 13 columns]

# %%
#inches
df['Inches']=df['Inches'].astype('float')
# Weight
# voy a comprobar si todo esta en kg 
# Verifica si TODOS los valores contienen 'kg'
cantidad_con_kg = df['Weight'].str.contains('kg', case=False).sum()
print(f"Valores con 'kg': {cantidad_con_kg} de {len(df)}")

# Cambiar la etiqueta e indicar que esta en kg 
df.rename(columns={'Weight': 'Weight_kg'}, inplace=True)
# borrar kg y pasarlo a numerico
df['Weight_kg'] = df['Weight_kg'].str.replace('kg', '', regex=False).str.strip()
df['Weight_kg'] = df['Weight_kg'].astype(float)

# Mostrar el resultado
print(df)
#ram
# Comprobar si todo esta GB
cantidad_con_gb = df['Ram'].str.contains('GB', case=False).sum()
print(f"Valores con 'GB': {cantidad_con_gb} de {len(df)}")
# Cambiar la etiqueta e indicar que esta en GB
df.rename(columns={'Ram': 'Ram_GB'}, inplace=True)
# borrar GB y pasarlo a numerico
df['Ram_GB'] = df['Ram_GB'].str.replace('GB', '', regex=False).str.strip()
df['Ram_GB'] = df['Ram_GB'].astype(int)
# Convertir los object en categoricas 
text_columns = ['Company', 'Product', 'TypeName', 'ScreenResolution', 'Cpu', 
                'Gpu', 'OpSys']

for col in text_columns:
    df[col] = df[col].astype('category')
    #ScreenResolution
#Agrupar las medidas en una nueva columna 
df['Resolución'] = df['ScreenResolution'].apply(
    lambda x: re.search(r'(\d{3,4}x\d{3,4})', x).group(0) if re.search(r'(\d{3,4}x\d{3,4})', x) else None)
#Crear otra variable para características de la pantalla

df['tipo_pantalla'] = df['ScreenResolution'].str.extract(r'^(\w+)')
df['tipo_pantalla'] = df['tipo_pantalla'].replace({
    '1366x768': 'HD',
    '1600x900':'HD+',
    '1920x1080':'Full HD',
    '1440x900':'WXGA+',
    '2560x1440':'Quad-HD'
    })

#Memoria
def clean_and_normalize_memory(value):
    value=str(value).lower().strip() # para que el valor sea un string
    match= re.match(r'(\d+(\.\d+)?)(\s*(gb|mb|tb)?)?', value)
    if match:
        numero= float(match.group(1)) #sacar el número
        unidad= match.group(3).strip() if match.group(3) else '' #captura la unidad
        # cambiar unidades
        if 'gb' in unidad or unidad =='':
            return numero
        elif 'mb' in unidad:
            return numero/ 1024
        elif 'tb' in unidad:
            return numero * 1024
    return None 
df['Memoria']=df['Memory'].apply(clean_and_normalize_memory)
# Función para extraer tipos de memoria
def extraer_tipos(almacenamiento):
    tipos = []
    if 'SSD' in almacenamiento:
        tipos.append('SSD')
    if 'HDD' in almacenamiento:
        tipos.append('HDD')
    if 'Flash Storage' in almacenamiento:
        tipos.append('Flash Storage')
    if 'Hybrid' in almacenamiento:
        tipos.append('Hybrid')
    return ', '.join(tipos)  # Combinar los tipos encontrados en una cadena separada por comas

# Crear una nueva columna con los tipos de memoria extraídos
df['Tipos_Memoria'] = df['Memory'].apply(extraer_tipos)

#Cpu
df['tipo_cpu'] = df['Cpu'].str.extract(r'^(.*)\s')
df['tipo_cpu'].value_counts()
# Comprobar si todo esta GB
cantidad_con_ghz = df['Cpu'].str.contains('GHz', case=False).sum()
print(f"Valores con 'GHz': {cantidad_con_ghz} de {len(df)}")
#Sacar la velocidad de cpu
df['velocidad_cpu_ghz'] = df['Cpu'].str.extract(r'(\d+(?:\.\d+)?)GHz')

#Gpu
df[['marca_gpu', 'modelo_gpu']] = df['Gpu'].str.extract(r'(\w+) (.*)')
df['modelo_gpu'].value_counts()
#OpSys
df['OpSys_general']= df['OpSys'].replace({ 
    'Windows 10':'Windows',
    'Windows 7':'Windows',
    'Windows 10 S':'Windows',
    'Linux':'Linux',
    'MacOS':'MacOS',
    'Mac OS X':'MacOS',
    'Android':'Android',
    'Chrome OS':'Chrome OS',
    'No OS':'Sin OS'
    })
df.drop(columns=['ScreenResolution', 'Cpu', 'Gpu','Memory'], inplace=True)
# Out:
# Valores con 'kg': 912 de 912
#      laptop_ID Company             Product            TypeName  Inches  \
# 0         1223    Dell       Inspiron 5567            Notebook    15.6
# 1           78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2         1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3          161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4          922      LG         Gram 14Z970           Ultrabook    14.0
# ..         ...     ...                 ...                 ...     ...
# 907        709  Lenovo   IdeaPad 320-15AST            Notebook    15.6
# 908        947  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3
# 909        590    Dell       Latitude 5580            Notebook    15.6
# 910       1143  Lenovo  Legion Y520-15IKBN              Gaming    15.6
# 911        531    Dell       Inspiron 5770            Notebook    17.3
#
#                                ScreenResolution                          Cpu  \
# 0                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 2              Quad HD+ / Touchscreen 3200x1800    Intel Core i5 7Y54 1.2GHz
# 3               Full HD / Touchscreen 1920x1080   Intel Core i7 8550U 1.8GHz
# 4     IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# ..                                          ...                          ...
# 907                           Full HD 1920x1080    AMD A9-Series 9420 2.9GHz
# 908  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6560U 2.2GHz
# 909                           Full HD 1920x1080   Intel Core i7 7600U 2.8GHz
# 910                 IPS Panel Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 911                 IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
#
#       Ram                Memory                      Gpu       OpSys  \
# 0     8GB             256GB SSD       AMD Radeon R7 M445  Windows 10
# 1     8GB               2TB HDD    Intel HD Graphics 620       No OS
# 2     8GB             256GB SSD    Intel HD Graphics 615  Windows 10
# 3     8GB             256GB SSD   Intel UHD Graphics 620  Windows 10
# 4     8GB             512GB SSD    Intel HD Graphics 620  Windows 10
# ..    ...                   ...                      ...         ...
# 907   4GB             256GB SSD           AMD Radeon 530  Windows 10
# 908  16GB               1TB SSD  Intel Iris Graphics 540  Windows 10
# 909  16GB             256GB SSD     Nvidia GeForce 930MX  Windows 10
# 910   8GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060       No OS
# 911   8GB  128GB SSD +  1TB HDD           AMD Radeon 530       Linux
#
#      Weight_kg  Price_euros
# 0         2.36       889.00
# 1         2.20       519.00
# 2         1.24      1813.00
# 3         1.56      1049.00
# 4         0.98      1899.00
# ..         ...          ...
# 907       2.20       399.00
# 908       1.30      1799.00
# 909       1.93      1537.39
# 910       2.40       989.00
# 911       2.80       889.00
#
# [912 rows x 13 columns]
# Valores con 'GB': 912 de 912
# Valores con 'GHz': 912 de 912
# /var/folders/pq/mppvlq_j3_7b5gpr_bpc5khm0000gn/T/ipykernel_76077/602261067.py:92: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['OpSys_general']= df['OpSys'].replace({

# %%
df
# Out:
#      laptop_ID Company             Product            TypeName  Inches  \
# 0         1223    Dell       Inspiron 5567            Notebook    15.6
# 1           78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2         1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3          161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4          922      LG         Gram 14Z970           Ultrabook    14.0
# ..         ...     ...                 ...                 ...     ...
# 907        709  Lenovo   IdeaPad 320-15AST            Notebook    15.6
# 908        947  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3
# 909        590    Dell       Latitude 5580            Notebook    15.6
# 910       1143  Lenovo  Legion Y520-15IKBN              Gaming    15.6
# 911        531    Dell       Inspiron 5770            Notebook    17.3
#
#      Ram_GB       OpSys  Weight_kg  Price_euros Resolución tipo_pantalla  \
# 0         8  Windows 10       2.36       889.00  1920x1080          Full
# 1         8       No OS       2.20       519.00  1920x1080          Full
# 2         8  Windows 10       1.24      1813.00  3200x1800          Quad
# 3         8  Windows 10       1.56      1049.00  1920x1080          Full
# 4         8  Windows 10       0.98      1899.00  1920x1080           IPS
# ..      ...         ...        ...          ...        ...           ...
# 907       4  Windows 10       2.20       399.00  1920x1080          Full
# 908      16  Windows 10       1.30      1799.00  3200x1800           IPS
# 909      16  Windows 10       1.93      1537.39  1920x1080          Full
# 910       8       No OS       2.40       989.00  1920x1080           IPS
# 911       8       Linux       2.80       889.00  1920x1080           IPS
#
#      Memoria Tipos_Memoria              tipo_cpu velocidad_cpu_ghz marca_gpu  \
# 0      256.0           SSD   Intel Core i5 7200U               2.5       AMD
# 1     2048.0           HDD   Intel Core i5 7200U               2.5     Intel
# 2      256.0           SSD    Intel Core i5 7Y54               1.2     Intel
# 3      256.0           SSD   Intel Core i7 8550U               1.8     Intel
# 4      512.0           SSD   Intel Core i7 7500U               2.7     Intel
# ..       ...           ...                   ...               ...       ...
# 907    256.0           SSD    AMD A9-Series 9420               2.9       AMD
# 908   1024.0           SSD   Intel Core i7 6560U               2.2     Intel
# 909    256.0           SSD   Intel Core i7 7600U               2.8    Nvidia
# 910    128.0      SSD, HDD  Intel Core i5 7300HQ               2.5    Nvidia
# 911    128.0      SSD, HDD   Intel Core i5 8250U               1.6       AMD
#
#             modelo_gpu OpSys_general
# 0       Radeon R7 M445       Windows
# 1      HD Graphics 620        Sin OS
# 2      HD Graphics 615       Windows
# 3     UHD Graphics 620       Windows
# 4      HD Graphics 620       Windows
# ..                 ...           ...
# 907         Radeon 530       Windows
# 908  Iris Graphics 540       Windows
# 909      GeForce 930MX       Windows
# 910   GeForce GTX 1060        Sin OS
# 911         Radeon 530         Linux
#
# [912 rows x 18 columns]

# %%
train= df[['laptop_ID','Inches','Price_euros','Memoria','Weight_kg','Ram_GB']]

# %%
#df.to_csv("Dataset/limpio.csv")

# %% [markdown]
# ### 1. Definir X e y

# %%
X = train.drop(['laptop_ID','Price_euros'], axis=1)
y = train['Price_euros'].copy()
X.shape
# Out:
# (912, 4)

# %%
y.shape
# Out:
# (912,)

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train
# Out:
#      Inches  Memoria  Weight_kg  Ram_GB
# 25     14.0    128.0       1.70       4
# 84     15.6   1024.0       2.25       4
# 10     15.6    256.0       2.00       8
# 342    15.6   1024.0       1.90       4
# 890    13.3    128.0       1.29       8
# ..      ...      ...        ...     ...
# 106    15.6   2048.0       2.02       8
# 270    15.6    500.0       1.90       8
# 860    14.0    256.0       1.36       8
# 435    15.6    256.0       2.20       8
# 102    17.3   1024.0       3.30       8
#
# [729 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 4. Sacar métricas, valorar el modelo
#
# Recuerda que en la competición se va a evaluar con la métrica de RMSE.

# %%
from sklearn.metrics import root_mean_squared_error

predictions = regressor.predict(X_test)

rmse = root_mean_squared_error(y_test, predictions)

# %%
print(rmse)
# Out:
# 487.4386731948668

# %% [markdown]
# ### 4. Mete tus predicciones en un dataframe.
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
X_pred = pd.read_csv("/Users/isaromobru/Desktop/DS102024_/ordenadores/test.csv")
X_pred.head()
# Out:
#    laptop_ID   Company                 Product   TypeName  Inches  \
# 0        539      Asus  Zenbook UX510UW-FI095T   Notebook    15.6
# 1        327      Asus  ZenBook UX410UA-GV183T   Notebook    14.0
# 2        563  Mediacom           SmartBook 130   Notebook    13.3
# 3         13     Apple             MacBook Pro  Ultrabook    15.4
# 4        935        HP           EliteBook 850  Ultrabook    15.6
#
#                      ScreenResolution                          Cpu   Ram  \
# 0     IPS Panel 4K Ultra HD 3840x2160   Intel Core i7 7500U 2.7GHz   8GB
# 1                   Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 2         IPS Panel Full HD 1920x1080  Intel Atom x5-Z8350 1.44GHz   4GB
# 3  IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz  16GB
# 4                   Full HD 1920x1080   Intel Core i7 6500U 2.5GHz   8GB
#
#                  Memory                      Gpu       OpSys  Weight
# 0  256GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10     2kg
# 1             256GB SSD    Intel HD Graphics 620  Windows 10     2kg
# 2    32GB Flash Storage        Intel HD Graphics  Windows 10  1.35kg
# 3             256GB SSD       AMD Radeon Pro 555       macOS  1.83kg
# 4             256GB SSD      AMD Radeon R7 M365X  Windows 10  1.84kg

# %%
#inches
X_pred['Inches']=X_pred['Inches'].astype('float')
# Weight
# voy a comprobar si todo esta en kg 
# Verifica si TODOS los valores contienen 'kg'
cantidad_con_kg = X_pred['Weight'].str.contains('kg', case=False).sum()
print(f"Valores con 'kg': {cantidad_con_kg} de {len( X_pred)}")

# Cambiar la etiqueta e indicar que esta en kg 
X_pred.rename(columns={'Weight': 'Weight_kg'}, inplace=True)
# borrar kg y pasarlo a numerico
X_pred['Weight_kg'] = X_pred['Weight_kg'].str.replace('kg', '', regex=False).str.strip()
X_pred['Weight_kg'] = X_pred['Weight_kg'].astype(float)

# Mostrar el resultado
#print(df)
#ram
# Comprobar si todo esta GB
cantidad_con_gb = X_pred['Ram'].str.contains('GB', case=False).sum()
print(f"Valores con 'GB': {cantidad_con_gb} de {len(X_pred)}")
# Cambiar la etiqueta e indicar que esta en GB
X_pred.rename(columns={'Ram': 'Ram_GB'}, inplace=True)
# borrar GB y pasarlo a numerico
X_pred['Ram_GB'] = X_pred['Ram_GB'].str.replace('GB', '', regex=False).str.strip()
X_pred['Ram_GB'] = X_pred['Ram_GB'].astype(int)
# Convertir los object en categoricas 
text_columns = ['Company', 'Product', 'TypeName', 'ScreenResolution', 'Cpu', 
                'Gpu', 'OpSys']

for col in text_columns:
    X_pred[col] = X_pred[col].astype('category')
    #ScreenResolution
#Agrupar las medidas en una nueva columna 
X_pred['Resolución'] =  X_pred['ScreenResolution'].apply(
    lambda x: re.search(r'(\d{3,4}x\d{3,4})', x).group(0) if re.search(r'(\d{3,4}x\d{3,4})', x) else None)
#Crear otra variable para características de la pantalla

X_pred['tipo_pantalla'] =  X_pred['ScreenResolution'].str.extract(r'^(\w+)')
X_pred['tipo_pantalla'] =  X_pred['tipo_pantalla'].replace({
    '1366x768': 'HD',
    '1600x900':'HD+',
    '1920x1080':'Full HD',
    '1440x900':'WXGA+',
    '2560x1440':'Quad-HD'
    })

#Memoria
def clean_and_normalize_memory(value):
    value=str(value).lower().strip() # para que el valor sea un string
    match= re.match(r'(\d+(\.\d+)?)(\s*(gb|mb|tb)?)?', value)
    if match:
        numero= float(match.group(1)) #sacar el número
        unidad= match.group(3).strip() if match.group(3) else '' #captura la unidad
        # cambiar unidades
        if 'gb' in unidad or unidad =='':
            return numero
        elif 'mb' in unidad:
            return numero/ 1024
        elif 'tb' in unidad:
            return numero * 1024
    return None 
X_pred['Memoria']= X_pred['Memory'].apply(clean_and_normalize_memory)
# Función para extraer tipos de memoria
def extraer_tipos(almacenamiento):
    tipos = []
    if 'SSD' in almacenamiento:
        tipos.append('SSD')
    if 'HDD' in almacenamiento:
        tipos.append('HDD')
    if 'Flash Storage' in almacenamiento:
        tipos.append('Flash Storage')
    if 'Hybrid' in almacenamiento:
        tipos.append('Hybrid')
    return ', '.join(tipos)  # Combinar los tipos encontrados en una cadena separada por comas

# Crear una nueva columna con los tipos de memoria extraídos
X_pred['Tipos_Memoria'] =  X_pred['Memory'].apply(extraer_tipos)

#Cpu
X_pred['tipo_cpu'] =  X_pred['Cpu'].str.extract(r'^(.*)\s')
X_pred['tipo_cpu'].value_counts()
# Comprobar si todo esta GB
cantidad_con_ghz =  X_pred['Cpu'].str.contains('GHz', case=False).sum()
print(f"Valores con 'GHz': {cantidad_con_ghz} de {len( X_pred)}")
#Sacar la velocidad de cpu
X_pred['velocidad_cpu_ghz'] =  X_pred['Cpu'].str.extract(r'(\d+(?:\.\d+)?)GHz')

#Gpu
X_pred[['marca_gpu', 'modelo_gpu']] =  X_pred['Gpu'].str.extract(r'(\w+) (.*)')
X_pred['modelo_gpu'].value_counts()
#OpSys
X_pred['OpSys_general']=  X_pred['OpSys'].replace({ 
    'Windows 10':'Windows',
    'Windows 7':'Windows',
    'Windows 10 S':'Windows',
    'Linux':'Linux',
    'MacOS':'MacOS',
    'Mac OS X':'MacOS',
    'Android':'Android',
    'Chrome OS':'Chrome OS',
    'No OS':'Sin OS'
    })
X_pred.drop(columns=['ScreenResolution', 'Cpu', 'Gpu','Memory'], inplace=True)
# Out:
# Valores con 'kg': 391 de 391
# Valores con 'GB': 391 de 391
# Valores con 'GHz': 391 de 391
# /var/folders/pq/mppvlq_j3_7b5gpr_bpc5khm0000gn/T/ipykernel_76077/1406228543.py:92: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   X_pred['OpSys_general']=  X_pred['OpSys'].replace({

# %%
X_pred.shape
# Out:
# (391, 12)

# %%
'laptop_ID','Inches','Price_euros','Memoria','Weight_kg','Ram_GB'
# Out:
# ('laptop_ID', 'Inches', 'Price_euros', 'Memoria', 'Weight_kg', 'Ram_GB')

# %%
X_pred
# Out:
#      laptop_ID   Company                 Product   TypeName  Inches  \
# 0          539      Asus  Zenbook UX510UW-FI095T   Notebook    15.6
# 1          327      Asus  ZenBook UX410UA-GV183T   Notebook    14.0
# 2          563  Mediacom           SmartBook 130   Notebook    13.3
# 3           13     Apple             MacBook Pro  Ultrabook    15.4
# 4          935        HP           EliteBook 850  Ultrabook    15.6
# ..         ...       ...                     ...        ...     ...
# 386        742    Lenovo             ThinkPad 13   Notebook    13.3
# 387        660      Dell                  XPS 13  Ultrabook    13.3
# 388        983    Lenovo       IdeaPad 310-15IKB   Notebook    15.6
# 389       1137        HP          EliteBook 1040   Notebook    14.0
# 390        556    Lenovo           ThinkPad T570   Notebook    15.6
#
#                        ScreenResolution                          Cpu   Ram  \
# 0       IPS Panel 4K Ultra HD 3840x2160   Intel Core i7 7500U 2.7GHz   8GB
# 1                     Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 2           IPS Panel Full HD 1920x1080  Intel Atom x5-Z8350 1.44GHz   4GB
# 3    IPS Panel Retina Display 2880x1800         Intel Core i7 2.8GHz  16GB
# 4                     Full HD 1920x1080   Intel Core i7 6500U 2.5GHz   8GB
# ..                                  ...                          ...   ...
# 386         IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 387                   Full HD 1920x1080   Intel Core i5 8250U 1.6GHz   8GB
# 388                   Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   6GB
# 389                   Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8GB
# 390         IPS Panel Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
#
#                    Memory                      Gpu       OpSys  Weight
# 0    256GB SSD +  1TB HDD  Nvidia GeForce GTX 960M  Windows 10     2kg
# 1               256GB SSD    Intel HD Graphics 620  Windows 10     2kg
# 2      32GB Flash Storage        Intel HD Graphics  Windows 10  1.35kg
# 3               256GB SSD       AMD Radeon Pro 555       macOS  1.83kg
# 4               256GB SSD      AMD Radeon R7 M365X  Windows 10  1.84kg
# ..                    ...                      ...         ...     ...
# 386             256GB SSD    Intel HD Graphics 620  Windows 10  1.44kg
# 387             256GB SSD   Intel UHD Graphics 620  Windows 10   1.2kg
# 388             256GB SSD     Nvidia GeForce 920MX  Windows 10   2.4kg
# 389             256GB SSD    Intel HD Graphics 520   Windows 7  1.43kg
# 390             512GB SSD    Intel HD Graphics 620  Windows 10  1.99kg
#
# [391 rows x 12 columns]

# %%
X_pred= X_pred[['Inches','Memoria','Weight_kg','Ram_GB']]

# %%
predictions_submit = regressor.predict(X_pred)
predictions_submit
# Out:
# array([1080.35086004, 1185.86350297,  857.43532973, 1878.12638381,
#        1073.56657848,  639.70201578, 1835.51355178,  716.54889423,
#         985.91547517,  726.55788444, 1093.49540555, 1773.21936401,
#         524.53645495,  639.70201578, 1025.84980049, 1893.96771054,
#         769.47373922, 1104.03557583, 1923.45173185,  515.20806781,
#        1270.37075955, 1198.10387648, 1736.83799095,  643.94219176,
#         842.42790727,  720.01069727,  691.09844578, 1923.45173185,
#        1173.14297505, 1030.08997646, 1902.96194636, 1198.10387648,
#         516.9041382 , 1934.04883551, 1109.97182219,  815.51372442,
#        1025.84980049, 1798.20000323,  925.52203739, 1158.72637675,
#        1071.0224729 , 1161.69449993, 1187.11968761, 1105.41030003,
#         963.68362114,  917.04168545,  688.69366473, 3239.25717602,
#         916.19365025,  809.4106715 ,  532.59278929,  926.37007259,
#         697.17401667,  521.14431417, 1101.5517399 ,  626.04539073,
#        1038.5703284 ,  997.50089113, 1801.71268331, 1168.90279908,
#         834.61573414,  708.56222214, 1088.83121198,  527.50457813,
#         814.66568923, 1742.35021971,  639.70201578, 1216.11062261,
#        1116.75610374,  909.22547714, 1033.49423124, 1080.35086004,
#        1080.35086004,  626.98148787,  544.46528201, 1804.2567889 ,
#        1215.91261556,  828.25547018, 1319.29932069, 1084.16701841,
#        1721.14933985, 1082.04693043, 1837.49669893,  525.38449014,
#         925.52203739, 1253.40430352, 1881.24718262, 1163.81458791,
#         516.9041382 , 1087.13514159,  688.69366473,  830.13139696,
#        1908.5508463 , 1822.27660029,  921.28186142,  997.92490873,
#        1149.46239211,  908.56133351, 1827.88123503,  635.46183981,
#        1125.23645568,  720.85873246, 1872.76683068,  724.60522857,
#         719.09299981,  525.38449014, 1116.75610374, 1053.4109443 ,
#        1173.14297505,  795.4180908 , 1630.65065267,  767.91721663,
#        1010.64543664, 1802.4401792 , 1097.31156392,  740.97448274,
#        1883.64687826,  912.37749188, 1170.59886947,  656.28205209,
#        1835.51355178, 1181.623327  , 1850.94472274,  807.29058352,
#        1164.66262311,  802.20237235, 1190.77023845,  625.71225324,
#         648.18236773,  928.49016057,  684.45348876,  510.96789184,
#        1074.41461368, 1205.73619322, 1193.8637005 ,  921.28186142,
#         832.14129082, 1888.03146418, 1073.56657848, 1087.98317679,
#         786.08970366, 1205.31217563,  696.68972942,  809.15346047,
#         716.61855649,  827.40743499, 1075.26264887,  832.14129082,
#         459.91924272,  521.14431417, 1167.01698732, 2684.77000796,
#        1889.58312462, 1101.5517399 , 1098.02027459, 1912.00325673,
#        1148.19033932, 1899.33552936,  447.1987148 ,  635.46183981,
#        1209.9763692 , 1107.91200385, 1206.58422842, 1820.53599505,
#         648.18236773,  922.55391421, 1094.34344074, 1202.34405245,
#        1129.47663166, 1081.19889523, 1896.25433598, 1076.53470166,
#        1853.32229086, 1215.06458036, 1677.29258836, 1906.06701037,
#        1722.42139264,  793.82600826, 1168.90279908, 1116.75610374,
#        1899.70674641, 1198.52789407, 1142.25409295, 1115.90806855,
#        1925.08753259,  862.89736493, 1879.35390175, 1161.69449993,
#        1084.72464057, 1149.46239211, 1110.50890998, 1937.86499389,
#        1872.99363779, 1187.11968761, 3390.3903796 , 1207.43226361,
#        1292.74753558,  843.09608608, 1521.13382696, 1093.07138795,
#        1835.51355178,  940.36265329, 1000.40874466, 1822.34926847,
#         805.59864597,  939.0906005 , 1934.89687071,  510.96789184,
#        1833.25652296,  694.20589349, 1073.56657848,  921.28186142,
#        3453.87247987, 1736.83799095,  524.53645495,  926.37007259,
#        2041.8069053 ,  525.38449014,  625.28541748, 1138.01391698,
#         510.54387424, 1964.93771761, 1887.41023609, 1088.44959614,
#         925.52203739, 1107.8517342 , 1157.03030636, 1085.8630888 ,
#        1890.57556976,  963.34985808, 1199.37592927, 1088.83121198,
#        1202.34405245,  921.28186142, 1951.8575746 , 1082.89496562,
#        1210.82440439, 1133.71680763,  684.45348876,  857.43532973,
#        1154.06218318, 1215.06458036,  929.76221336, 1161.69449993,
#        1878.70307704,  708.13820455,  727.57335175,  939.0906005 ,
#         908.56133351, 1253.40430352,  409.45175604, 1075.26264887,
#         525.38449014, 1101.5517399 ,  524.53645495, 1074.41461368,
#         626.13345267,  520.29627897, 1093.07138795, 1899.41633338,
#        1205.31217563,  716.61855649,  722.90915818, 1818.83992466,
#        1094.34344074, 1196.82769084,  807.29058352,  716.54889423,
#        1906.06701037,  625.28541748,  835.88778693,  533.86484208,
#        1255.10037391,  684.45348876, 1208.7043164 , 1186.71153816,
#        1030.08997646,  727.57335175, 1871.84212431,  625.28541748,
#        3364.10128857,  631.22166384, 1166.3586935 , 1105.79191587,
#         933.76983008,  768.05547215, 1215.91261556, 1067.63033212,
#         925.52203739,  965.30233687,  635.46183981,  686.14955915,
#         516.9041382 ,  966.67286036, 1073.56657848,  678.5172424 ,
#         813.39363644, 1198.10387648,  761.2711906 ,  722.26847312,
#        1105.36789827, 1078.65478965, 1798.20000323,  956.20102595,
#         717.2294973 ,  950.71893201, 1206.58422842, 1271.68077839,
#        1025.84980049,  639.70201578, 1843.85696289,  989.44455678,
#        1202.34405245,  939.0906005 , 1116.75610374,  631.22166384,
#        1104.03557583,  612.70390383, 1080.35086004, 1198.10387648,
#         617.56503878, 1317.1792327 ,  720.85873246,  691.09844578,
#         843.09608608,  632.91773423, 1163.82205703, 1168.90279908,
#         921.28186142, 1421.38342382, 1205.31217563, 1201.49601725,
#         865.16611718, 1097.31156392, 1909.08793409, 1082.47094802,
#         635.46183981, 1085.8630888 , 1863.66525065, 1173.14297505,
#         914.90037962,  815.77093546,  633.34175183,  842.42790727,
#         720.85873246, 1938.28901149,  804.27510733,  639.70201578,
#        1863.66525065, 1170.17485187, 1093.07138795,  926.37007259,
#        1315.05914471, 1088.83121198, 1151.94209519,  648.18236773,
#        1198.52789407, 1853.32229086, 1932.35276513, 1090.10326477,
#         525.38449014, 1120.99627971, 1025.84980049,  805.59864597,
#         882.4021744 , 1093.07138795, 1880.62595454,  842.85192487,
#        1222.88078867,  921.28186142, 1116.75610374, 1038.5703284 ,
#        1778.27117616, 1253.40430352, 1093.07138795, 1031.28535807,
#         625.28541748, 1019.12578859,  997.92490873, 1835.51355178,
#        1080.35086004, 1194.2877181 , 1025.42578289,  639.70201578,
#         632.91773423, 1833.25652296, 1208.28029881, 1198.10387648,
#         899.36287828, 1161.69449993, 1024.07705892])

# %%
sample = pd.read_csv("/Users/isaromobru/Desktop/DS102024_/ordenadores/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_euros
# 0        539          650
# 1        327          650
# 2        563          650
# 3         13          650
# 4        935          500

# %%
sample.shape
# Out:
# (391, 2)

# %%
sample
# Out:
#      laptop_ID  Price_euros
# 0          539          650
# 1          327          650
# 2          563          650
# 3           13          650
# 4          935          500
# ..         ...          ...
# 386        742          650
# 387        660          650
# 388        983          650
# 389       1137          500
# 390        556          500
#
# [391 rows x 2 columns]

# %%
submission = pd.DataFrame({"laptop_ID": sample['laptop_ID'], "Price_euros": predictions_submit})

# %%
submission.head()
# Out:
#    laptop_ID  Price_euros
# 0        539  1080.350860
# 1        327  1185.863503
# 2        563   857.435330
# 3         13  1878.126384
# 4        935  1073.566578

# %%
def chequeator(df_to_submit,version):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit['laptop_ID'].all() == sample['laptop_ID'].all():
                print("You're ready to submit!")
                submission.to_csv(f"submission_{version}.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto de Clara: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `diamonds_test.csv`. Lloro.")

# %%
chequeator(submission,1)
# Out:
# You're ready to submit!
