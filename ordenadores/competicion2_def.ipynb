# %% [markdown]
# ### Librerias

# %%
import pandas as pd

import urllib.request
from PIL import Image
import re
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data

# %%
df=pd.read_csv('/Users/isaromobru/Desktop/DS102024_/ordenadores/train.csv')

# %% [markdown]
# ## Data exploración

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         912 non-null    int64
#  1   Company           912 non-null    object
#  2   Product           912 non-null    object
#  3   TypeName          912 non-null    object
#  4   Inches            912 non-null    float64
#  5   ScreenResolution  912 non-null    object
#  6   Cpu               912 non-null    object
#  7   Ram               912 non-null    object
#  8   Memory            912 non-null    object
#  9   Gpu               912 non-null    object
#  10  OpSys             912 non-null    object
#  11  Weight            912 non-null    object
#  12  Price_euros       912 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 92.8+ KB

# %%
df.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  \
# 0       1223    Dell       Inspiron 5567            Notebook    15.6
# 1         78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2       1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3        161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4        922      LG         Gram 14Z970           Ultrabook    14.0
#
#                             ScreenResolution                         Cpu  Ram  \
# 0                          Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
# 1                          Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
# 2           Quad HD+ / Touchscreen 3200x1800   Intel Core i5 7Y54 1.2GHz  8GB
# 3            Full HD / Touchscreen 1920x1080  Intel Core i7 8550U 1.8GHz  8GB
# 4  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz  8GB
#
#       Memory                     Gpu       OpSys  Weight  Price_euros
# 0  256GB SSD      AMD Radeon R7 M445  Windows 10  2.36kg        889.0
# 1    2TB HDD   Intel HD Graphics 620       No OS   2.2kg        519.0
# 2  256GB SSD   Intel HD Graphics 615  Windows 10  1.24kg       1813.0
# 3  256GB SSD  Intel UHD Graphics 620  Windows 10  1.56kg       1049.0
# 4  512GB SSD   Intel HD Graphics 620  Windows 10  0.98kg       1899.0

# %% [markdown]
# ## Data processing

# %%
df
# Out:
#      laptop_ID Company             Product            TypeName  Inches  \
# 0         1223    Dell       Inspiron 5567            Notebook    15.6
# 1           78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2         1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3          161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4          922      LG         Gram 14Z970           Ultrabook    14.0
# ..         ...     ...                 ...                 ...     ...
# 907        709  Lenovo   IdeaPad 320-15AST            Notebook    15.6
# 908        947  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3
# 909        590    Dell       Latitude 5580            Notebook    15.6
# 910       1143  Lenovo  Legion Y520-15IKBN              Gaming    15.6
# 911        531    Dell       Inspiron 5770            Notebook    17.3
#
#                                ScreenResolution                          Cpu  \
# 0                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 2              Quad HD+ / Touchscreen 3200x1800    Intel Core i5 7Y54 1.2GHz
# 3               Full HD / Touchscreen 1920x1080   Intel Core i7 8550U 1.8GHz
# 4     IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# ..                                          ...                          ...
# 907                           Full HD 1920x1080    AMD A9-Series 9420 2.9GHz
# 908  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6560U 2.2GHz
# 909                           Full HD 1920x1080   Intel Core i7 7600U 2.8GHz
# 910                 IPS Panel Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 911                 IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 0     8GB             256GB SSD       AMD Radeon R7 M445  Windows 10  2.36kg
# 1     8GB               2TB HDD    Intel HD Graphics 620       No OS   2.2kg
# 2     8GB             256GB SSD    Intel HD Graphics 615  Windows 10  1.24kg
# 3     8GB             256GB SSD   Intel UHD Graphics 620  Windows 10  1.56kg
# 4     8GB             512GB SSD    Intel HD Graphics 620  Windows 10  0.98kg
# ..    ...                   ...                      ...         ...     ...
# 907   4GB             256GB SSD           AMD Radeon 530  Windows 10   2.2kg
# 908  16GB               1TB SSD  Intel Iris Graphics 540  Windows 10   1.3kg
# 909  16GB             256GB SSD     Nvidia GeForce 930MX  Windows 10  1.93kg
# 910   8GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060       No OS   2.4kg
# 911   8GB  128GB SSD +  1TB HDD           AMD Radeon 530       Linux   2.8kg
#
#      Price_euros
# 0         889.00
# 1         519.00
# 2        1813.00
# 3        1049.00
# 4        1899.00
# ..           ...
# 907       399.00
# 908      1799.00
# 909      1537.39
# 910       989.00
# 911       889.00
#
# [912 rows x 13 columns]

# %%
#inches
df['Inches']=df['Inches'].astype('float')
# Weight
# voy a comprobar si todo esta en kg 
# Verifica si TODOS los valores contienen 'kg'
cantidad_con_kg = df['Weight'].str.contains('kg', case=False).sum()
print(f"Valores con 'kg': {cantidad_con_kg} de {len(df)}")

# Cambiar la etiqueta e indicar que esta en kg 
df.rename(columns={'Weight': 'Weight_kg'}, inplace=True)
# borrar kg y pasarlo a numerico
df['Weight_kg'] = df['Weight_kg'].str.replace('kg', '', regex=False).str.strip()
df['Weight_kg'] = df['Weight_kg'].astype(float)

# Mostrar el resultado
print(df)
#ram
# Comprobar si todo esta GB
cantidad_con_gb = df['Ram'].str.contains('GB', case=False).sum()
print(f"Valores con 'GB': {cantidad_con_gb} de {len(df)}")
# Cambiar la etiqueta e indicar que esta en GB
df.rename(columns={'Ram': 'Ram_GB'}, inplace=True)
# borrar GB y pasarlo a numerico
df['Ram_GB'] = df['Ram_GB'].str.replace('GB', '', regex=False).str.strip()
df['Ram_GB'] = df['Ram_GB'].astype(int)
# Convertir los object en categoricas 
text_columns = ['Company', 'Product', 'TypeName', 'ScreenResolution', 'Cpu', 
                'Gpu', 'OpSys']

for col in text_columns:
    df[col] = df[col].astype('category')
    #ScreenResolution
#Agrupar las medidas en una nueva columna 
df['Resolución'] = df['ScreenResolution'].apply(
    lambda x: re.search(r'(\d{3,4}x\d{3,4})', x).group(0) if re.search(r'(\d{3,4}x\d{3,4})', x) else None)
#Crear otra variable para características de la pantalla

df['tipo_pantalla'] = df['ScreenResolution'].str.extract(r'^(\w+)')
df['tipo_pantalla'] = df['tipo_pantalla'].replace({
    '1366x768': 'HD',
    '1600x900':'HD+',
    '1920x1080':'Full HD',
    '1440x900':'WXGA+',
    '2560x1440':'Quad-HD'
    })

#Memoria
def clean_and_normalize_memory(value):
    value=str(value).lower().strip() # para que el valor sea un string
    match= re.match(r'(\d+(\.\d+)?)(\s*(gb|mb|tb)?)?', value)
    if match:
        numero= float(match.group(1)) #sacar el número
        unidad= match.group(3).strip() if match.group(3) else '' #captura la unidad
        # cambiar unidades
        if 'gb' in unidad or unidad =='':
            return numero
        elif 'mb' in unidad:
            return numero/ 1024
        elif 'tb' in unidad:
            return numero * 1024
    return None 
df['Memoria']=df['Memory'].apply(clean_and_normalize_memory)
# Función para extraer tipos de memoria
def extraer_tipos(almacenamiento):
    tipos = []
    if 'SSD' in almacenamiento:
        tipos.append('SSD')
    if 'HDD' in almacenamiento:
        tipos.append('HDD')
    if 'Flash Storage' in almacenamiento:
        tipos.append('Flash Storage')
    if 'Hybrid' in almacenamiento:
        tipos.append('Hybrid')
    return ', '.join(tipos)  # Combinar los tipos encontrados en una cadena separada por comas

# Crear una nueva columna con los tipos de memoria extraídos
df['Tipos_Memoria'] = df['Memory'].apply(extraer_tipos)

#Cpu
df['tipo_cpu'] = df['Cpu'].str.extract(r'^(.*)\s')
df['tipo_cpu'].value_counts()
# Comprobar si todo esta GB
cantidad_con_ghz = df['Cpu'].str.contains('GHz', case=False).sum()
print(f"Valores con 'GHz': {cantidad_con_ghz} de {len(df)}")
#Sacar la velocidad de cpu
df['velocidad_cpu_ghz'] = df['Cpu'].str.extract(r'(\d+(?:\.\d+)?)GHz')

#Gpu
df[['marca_gpu', 'modelo_gpu']] = df['Gpu'].str.extract(r'(\w+) (.*)')
df['modelo_gpu'].value_counts()
#OpSys
df['OpSys_general']= df['OpSys'].replace({ 
    'Windows 10':'Windows',
    'Windows 7':'Windows',
    'Windows 10 S':'Windows',
    'Linux':'Linux',
    'MacOS':'MacOS',
    'Mac OS X':'MacOS',
    'Android':'Android',
    'Chrome OS':'Chrome OS',
    'No OS':'Sin OS'
    })
df.drop(columns=['ScreenResolution', 'Cpu', 'Gpu','Memory'], inplace=True)
# Out:
# Valores con 'kg': 912 de 912
#      laptop_ID Company             Product            TypeName  Inches  \
# 0         1223    Dell       Inspiron 5567            Notebook    15.6
# 1           78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6
# 2         1267    Dell              XPS 13  2 in 1 Convertible    13.3
# 3          161    Dell       Inspiron 5579  2 in 1 Convertible    15.6
# 4          922      LG         Gram 14Z970           Ultrabook    14.0
# ..         ...     ...                 ...                 ...     ...
# 907        709  Lenovo   IdeaPad 320-15AST            Notebook    15.6
# 908        947  Lenovo      Yoga 900-13ISK  2 in 1 Convertible    13.3
# 909        590    Dell       Latitude 5580            Notebook    15.6
# 910       1143  Lenovo  Legion Y520-15IKBN              Gaming    15.6
# 911        531    Dell       Inspiron 5770            Notebook    17.3
#
#                                ScreenResolution                          Cpu  \
# 0                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1                             Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 2              Quad HD+ / Touchscreen 3200x1800    Intel Core i5 7Y54 1.2GHz
# 3               Full HD / Touchscreen 1920x1080   Intel Core i7 8550U 1.8GHz
# 4     IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# ..                                          ...                          ...
# 907                           Full HD 1920x1080    AMD A9-Series 9420 2.9GHz
# 908  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6560U 2.2GHz
# 909                           Full HD 1920x1080   Intel Core i7 7600U 2.8GHz
# 910                 IPS Panel Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 911                 IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
#
#       Ram                Memory                      Gpu       OpSys  \
# 0     8GB             256GB SSD       AMD Radeon R7 M445  Windows 10
# 1     8GB               2TB HDD    Intel HD Graphics 620       No OS
# 2     8GB             256GB SSD    Intel HD Graphics 615  Windows 10
# 3     8GB             256GB SSD   Intel UHD Graphics 620  Windows 10
# 4     8GB             512GB SSD    Intel HD Graphics 620  Windows 10
# ..    ...                   ...                      ...         ...
# 907   4GB             256GB SSD           AMD Radeon 530  Windows 10
# 908  16GB               1TB SSD  Intel Iris Graphics 540  Windows 10
# 909  16GB             256GB SSD     Nvidia GeForce 930MX  Windows 10
# 910   8GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1060       No OS
# 911   8GB  128GB SSD +  1TB HDD           AMD Radeon 530       Linux
#
#      Weight_kg  Price_euros
# 0         2.36       889.00
# 1         2.20       519.00
# 2         1.24      1813.00
# 3         1.56      1049.00
# 4         0.98      1899.00
# ..         ...          ...
# 907       2.20       399.00
# 908       1.30      1799.00
# 909       1.93      1537.39
# 910       2.40       989.00
# 911       2.80       889.00
#
# [912 rows x 13 columns]
# Valores con 'GB': 912 de 912
# Valores con 'GHz': 912 de 912
# /var/folders/pq/mppvlq_j3_7b5gpr_bpc5khm0000gn/T/ipykernel_97214/602261067.py:92: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['OpSys_general']= df['OpSys'].replace({

# %%
df.head()
# Out:
#    laptop_ID Company             Product            TypeName  Inches  Ram_GB  \
# 0       1223    Dell       Inspiron 5567            Notebook    15.6       8
# 1         78  Lenovo  IdeaPad 320-15IKBN            Notebook    15.6       8
# 2       1267    Dell              XPS 13  2 in 1 Convertible    13.3       8
# 3        161    Dell       Inspiron 5579  2 in 1 Convertible    15.6       8
# 4        922      LG         Gram 14Z970           Ultrabook    14.0       8
#
#         OpSys  Weight_kg  Price_euros Resolución tipo_pantalla  Memoria  \
# 0  Windows 10       2.36        889.0  1920x1080          Full    256.0
# 1       No OS       2.20        519.0  1920x1080          Full   2048.0
# 2  Windows 10       1.24       1813.0  3200x1800          Quad    256.0
# 3  Windows 10       1.56       1049.0  1920x1080          Full    256.0
# 4  Windows 10       0.98       1899.0  1920x1080           IPS    512.0
#
#   Tipos_Memoria             tipo_cpu velocidad_cpu_ghz marca_gpu  \
# 0           SSD  Intel Core i5 7200U               2.5       AMD
# 1           HDD  Intel Core i5 7200U               2.5     Intel
# 2           SSD   Intel Core i5 7Y54               1.2     Intel
# 3           SSD  Intel Core i7 8550U               1.8     Intel
# 4           SSD  Intel Core i7 7500U               2.7     Intel
#
#          modelo_gpu OpSys_general
# 0    Radeon R7 M445       Windows
# 1   HD Graphics 620        Sin OS
# 2   HD Graphics 615       Windows
# 3  UHD Graphics 620       Windows
# 4   HD Graphics 620       Windows

# %%
#definición para procesar los datoa 
def procesar_datos_regresion(X, columnas_numericas, columnas_categoricas, columna_precio=None, scaler=None, encoder=None, fit=True):
    """
    Procesa los datos para regresión lineal, permitiendo reutilizar scaler y encoder.
    
    Parameters:
    X: DataFrame de entrada
    columnas_numericas: lista de nombres de columnas numéricas
    columnas_categoricas: lista de nombres de columnas categóricas
    columna_precio: (opcional) nombre de la columna del precio
    scaler: (opcional) Scaler previamente ajustado
    encoder: (opcional) Encoder previamente ajustado
    fit: (bool) Si True, ajusta scaler y encoder; si False, solo transforma
    
    Returns:
    X_procesado: Variables predictoras procesadas
    y: Precio sin procesar (si está disponible)
    scaler: Scaler ajustado
    encoder: Encoder ajustado
    """
    X = X.copy()  # Evita modificar el DataFrame original
    y = X[columna_precio] if columna_precio and columna_precio in X.columns else None
    
    # Procesar variables numéricas**
    if fit or scaler is None:
        scaler = StandardScaler()
        X_numericas_scaled = scaler.fit_transform(X[columnas_numericas])
    else:
        X_numericas_scaled = scaler.transform(X[columnas_numericas])
    
    X_numericas_scaled = pd.DataFrame(X_numericas_scaled, columns=columnas_numericas, index=X.index)
    
    # Procesar variables categóricas**
    if fit or encoder is None:
        encoder = OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore')
        X_categoricas_encoded = encoder.fit_transform(X[columnas_categoricas])
    else:
        X_categoricas_encoded = encoder.transform(X[columnas_categoricas])
    
    X_categoricas_encoded = pd.DataFrame(X_categoricas_encoded, columns=encoder.get_feature_names_out(columnas_categoricas), index=X.index)
    
    #  Unir variables procesadas**
    X_procesado = pd.concat([X_numericas_scaled, X_categoricas_encoded], axis=1)
    
    return X_procesado, y, scaler, encoder

# -------------------------------------
# Paso 1: Procesar datos de entrenamiento**
# -------------------------------------
#columnas elegidas
columnas_numericas = ['Ram_GB', 'Inches', 'Memoria', 'velocidad_cpu_ghz', 'Weight_kg']
columnas_categoricas = ['Company', 'TypeName', 'OpSys']
columna_precio = 'Price_euros'

X_train, y_train, scaler, encoder = procesar_datos_regresion(
    df, columnas_numericas, columnas_categoricas, columna_precio, fit=True
) #procesamineto en train

# Entrenar modelo de train
modelo = LinearRegression()
modelo.fit(X_train, y_train)

# -------------------------------------
# Paso 2: Procesar nuevos datos (X_pred)
# -------------------------------------
X_pred = pd.read_csv("/Users/isaromobru/Desktop/DS102024_/ordenadores/test.csv")  # Cargar nuevos datos
# Aplicación de los mismos cambios de train a test de los datos
#inches
X_pred['Inches']=X_pred['Inches'].astype('float')
# Weight
# voy a comprobar si todo esta en kg 
# Verifica si TODOS los valores contienen 'kg'
cantidad_con_kg = X_pred['Weight'].str.contains('kg', case=False).sum()
print(f"Valores con 'kg': {cantidad_con_kg} de {len( X_pred)}")

# Cambiar la etiqueta e indicar que esta en kg 
X_pred.rename(columns={'Weight': 'Weight_kg'}, inplace=True)
# borrar kg y pasarlo a numerico
X_pred['Weight_kg'] = X_pred['Weight_kg'].str.replace('kg', '', regex=False).str.strip()
X_pred['Weight_kg'] = X_pred['Weight_kg'].astype(float)
#ram
# Comprobar si todo esta GB
cantidad_con_gb = X_pred['Ram'].str.contains('GB', case=False).sum()
print(f"Valores con 'GB': {cantidad_con_gb} de {len(X_pred)}")
# Cambiar la etiqueta e indicar que esta en GB
X_pred.rename(columns={'Ram': 'Ram_GB'}, inplace=True)
# borrar GB y pasarlo a numerico
X_pred['Ram_GB'] = X_pred['Ram_GB'].str.replace('GB', '', regex=False).str.strip()
X_pred['Ram_GB'] = X_pred['Ram_GB'].astype(int)
# Convertir los object en categoricas 
text_columns = ['Company', 'Product', 'TypeName', 'ScreenResolution', 'Cpu', 
                'Gpu', 'OpSys']

for col in text_columns:
    X_pred[col] = X_pred[col].astype('category')
    #ScreenResolution
#Agrupar las medidas en una nueva columna 
X_pred['Resolución'] =  X_pred['ScreenResolution'].apply(
    lambda x: re.search(r'(\d{3,4}x\d{3,4})', x).group(0) if re.search(r'(\d{3,4}x\d{3,4})', x) else None)
#Crear otra variable para características de la pantalla

X_pred['tipo_pantalla'] =  X_pred['ScreenResolution'].str.extract(r'^(\w+)')
X_pred['tipo_pantalla'] =  X_pred['tipo_pantalla'].replace({
    '1366x768': 'HD',
    '1600x900':'HD+',
    '1920x1080':'Full HD',
    '1440x900':'WXGA+',
    '2560x1440':'Quad-HD'
    })

#Memoria
def clean_and_normalize_memory(value): #funcion dentro de procesamiento de memoria
    value=str(value).lower().strip() # para que el valor sea un string
    match= re.match(r'(\d+(\.\d+)?)(\s*(gb|mb|tb)?)?', value)
    if match:
        numero= float(match.group(1)) #sacar el número
        unidad= match.group(3).strip() if match.group(3) else '' #captura la unidad
        # cambiar unidades
        if 'gb' in unidad or unidad =='':
            return numero
        elif 'mb' in unidad:
            return numero/ 1024
        elif 'tb' in unidad:
            return numero * 1024
    return None 
X_pred['Memoria']= X_pred['Memory'].apply(clean_and_normalize_memory)
# Función para extraer tipos de memoria
def extraer_tipos(almacenamiento):
    tipos = []
    if 'SSD' in almacenamiento:
        tipos.append('SSD')
    if 'HDD' in almacenamiento:
        tipos.append('HDD')
    if 'Flash Storage' in almacenamiento:
        tipos.append('Flash Storage')
    if 'Hybrid' in almacenamiento:
        tipos.append('Hybrid')
    return ', '.join(tipos)  # Combinar los tipos encontrados en una cadena separada por comas

# Crear una nueva columna con los tipos de memoria extraídos
X_pred['Tipos_Memoria'] =  X_pred['Memory'].apply(extraer_tipos)

#Cpu
X_pred['tipo_cpu'] =  X_pred['Cpu'].str.extract(r'^(.*)\s')
X_pred['tipo_cpu'].value_counts()
# Comprobar si todo esta GB
cantidad_con_ghz =  X_pred['Cpu'].str.contains('GHz', case=False).sum()
print(f"Valores con 'GHz': {cantidad_con_ghz} de {len( X_pred)}")
#Sacar la velocidad de cpu
X_pred['velocidad_cpu_ghz'] =  X_pred['Cpu'].str.extract(r'(\d+(?:\.\d+)?)GHz')

#Gpu
X_pred[['marca_gpu', 'modelo_gpu']] =  X_pred['Gpu'].str.extract(r'(\w+) (.*)')
X_pred['modelo_gpu'].value_counts()
#OpSys
X_pred['OpSys_general']=  X_pred['OpSys'].replace({ 
    'Windows 10':'Windows',
    'Windows 7':'Windows',
    'Windows 10 S':'Windows',
    'Linux':'Linux',
    'MacOS':'MacOS',
    'Mac OS X':'MacOS',
    'Android':'Android',
    'Chrome OS':'Chrome OS',
    'No OS':'Sin OS'
    })
X_pred.drop(columns=['ScreenResolution', 'Cpu', 'Gpu','Memory'], inplace=True)
#fin dela aplicacion de cambios de test
X_pred_procesado, _, _, _ = procesar_datos_regresion(
    X_pred, columnas_numericas, columnas_categoricas, columna_precio=None, scaler=scaler, encoder=encoder, fit=False
) #se aplica la funcion del principio para normalizar, etc
# Out:
# Valores con 'kg': 391 de 391
# Valores con 'GB': 391 de 391
# Valores con 'GHz': 391 de 391
# [ 939.45038343 1015.82721655  309.05363512 2251.90019272 1452.04230642
#   670.11837112 2020.26999137  699.94736695 1497.82887389  630.87294962
#  1058.78158608 1955.60270933  480.89677073  633.64480509 1274.9425974
#  2120.76240736   77.68369333 1045.1595141  1910.2240856   462.31458103
#  1567.22734537 1323.77620136 1912.47836074  665.8815392   638.83228239
#   704.00774998  830.41866144 1873.75051957 1381.25834612  798.71165419
#  1793.41367613 1260.50751254  227.40631243 2127.92901849 1113.11951325
#   179.3052241  1274.9425974  1721.67995338  842.70319208 1297.61805552
#  1948.08529216 1854.89136183 1685.02666196 1109.14013935 1254.22583119
#   788.91137555  626.30996378 3920.67540723 1044.03969515 1106.80243358
#   515.812986    712.19134525  612.13476473  330.86179291 1003.73118854
#   320.65080218 1140.04883878  917.54713795 1841.72886513 1107.17242124
#   734.10284312  660.25249424  741.3063536   400.93422591  599.1640802
#  1860.49796323  398.20458497 1146.20890435 1259.49207553  990.96459523
#   319.         1960.36815445  939.45038343  610.391275    408.76190682
#  1932.67798005 1166.62436363  857.00723568 1196.14188613 1326.7270962
#  1992.768719    936.44107007 1719.19768565  483.67128393  842.70319208
#  1037.54620939 1809.84833675 1074.72647003  137.73297138  861.90423426
#  1016.72300912  804.48180193 1724.56909967 2195.96996279  717.89935392
#  1256.09587394 1367.67386177  961.77085661 1837.02469873  764.76990873
#  1278.00171841  556.76969415 1856.65133734  593.66764487  666.81722408
#   169.52766777 1286.73015234 1337.87619991 1038.47092564  808.52286578
#  1469.56548887 1207.77626574  721.87291288 1735.55251942 1033.49332747
#   532.01802503 1889.61929404  788.50922007 1048.51155407  904.74839442
#  1993.03191456 1066.21605773 1742.29512489  847.36605072 1047.19935957
#  1077.04712894 1574.36803093  699.23154016  449.6332652   841.22497106
#   506.1282743   612.57306211  809.99628884 1534.49376623 1030.09822789
#   713.781049    935.27462233 2007.45493343 1011.81730866  992.33622857
#  1236.46500124 1405.36730868  621.4093093   213.99805284  674.54552908
#   981.89020358 1263.28604708  971.74818836  416.18220031  633.80237997
#  1180.28315291 2671.69788273 2136.53674645 1215.48786052 1330.70300972
#  1948.41725572 1491.2512929  2150.20686534  502.22198327  408.01556705
#  1377.98162295 1163.47696258 1048.50487499 1515.12223949  486.10683123
#  1897.43149866  959.94530262 1359.18294641 1151.83639373  842.48264179
#  1824.37654886 1039.76488791 1827.47517932 1152.57040655 1501.89195712
#  2740.40943598 1758.82333677 1164.47418038  988.2521786  1232.0198033
#  1832.53771572 1261.89476914  994.29422622 1011.18295202 1742.19854124
#  1281.24573261 2598.30192083 1471.54161874 1297.41397414 1331.20029574
#  1814.22095457 1977.30726027 1367.15970483 1630.31631292 3187.93911089
#  1254.55359182  826.6054663   948.20672524 1209.94087441  981.06808158
#  2002.03320835 1050.39662186  726.88824061 1925.90862304 1061.29807182
#  1100.94520109 1633.08070757  225.60969893 1610.15028465  553.16038457
#  1030.05409167 1155.45476123 3305.18614068 1442.03345915  572.0806858
#   809.00413926 2092.63965013  684.14851205  689.72683625 1028.87834701
#   507.93704977 1852.77426983 1578.45747653 1300.17606529  723.60405076
#  1081.08630688 1444.21695542  821.26889841 2015.77847306 2104.55982632
#  1228.19571633  728.51633571 1303.67345113  768.49139805 1779.75488684
#  1986.9284771  1170.9015447  1105.79391041  414.94435923  316.3542626
#  1333.77118592 1189.04397258  735.87561617 1378.19279805 2070.82116959
#   259.8370338   724.07858307 1100.94520109 1098.26987052 1556.03510353
#   652.15330173 1364.24251215  556.49103095  862.82852295  553.84390278
#  1032.82860488 1021.14074352  828.04840817 1100.03983785 1871.00187461
#  1728.69092731  686.61036974  811.9401311  1607.05645554 1049.61864367
#  1007.09890206  810.89248469  827.60484805 1965.46922928  562.06935515
#   835.07740695  675.42007812 1513.04572326  595.80161535 1358.45761648
#  1447.97609708  888.38499524  724.07858307 1922.74938572  466.8945202
#  3019.30362608  214.88674552 1851.91440147 2146.72492143 1272.47794384
#   594.31764241 1203.09792966 1319.82090003  968.72271412  572.43919613
#   764.76990873  732.38723871  301.86401851  312.53948444 1048.29087469
#   561.52235571  282.57505365 1260.50751254  584.05899235 1059.30419687
#  2473.97705888 1046.70117093 1898.19141014  233.62802306 1050.35085207
#   460.12229815  929.53311872 1487.76239928 1274.9425974   587.62018087
#  1794.84426881  912.80516131 1231.52546531 1011.27186004  995.59329717
#   769.13412569 1230.1969347   450.57559455 1130.47267734 1457.92324061
#   143.22436314 1134.36786901  779.6020102   793.94509541 1008.12177461
#   696.46067213 1364.93915199  988.2521786   775.80776029 1626.2046785
#  1582.79666319 1368.47327386  426.832601    978.78297843 2110.06322962
#   919.46415862  546.82510698  857.74246444 1826.74356878 1074.94449166
#   695.1233921   833.36226885  539.88882395  784.7265465   524.28704799
#  1935.8399036  1139.98620284  587.62018087 1790.27000275  949.64105499
#  1081.80305484 1336.61018741 1079.80596113 1067.93048879  881.29744772
#   287.01279209 1261.89476914 1827.47517932 1807.07933289  805.62523758
#   410.72415188 1069.38091259 1220.23224835 1061.29807182  731.15243336
#  1045.32948881 1481.80366477  774.04896245 1411.85460562  863.66623299
#  1286.73015234 1085.33848974 1832.9903497  1092.25655843 1351.77072831
#   824.21078735  375.71060513 1221.89437949 1079.58441718 2002.03320835
#  2392.12891919 1038.57605712  750.03511139  574.94353617  714.69745514
#  1762.61989872 1072.29068443 1224.03394651  942.08801987 1378.19279805
#  1037.57821921]
# /var/folders/pq/mppvlq_j3_7b5gpr_bpc5khm0000gn/T/ipykernel_97214/3957301932.py:163: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   X_pred['OpSys_general']=  X_pred['OpSys'].replace({

# %%
#Calculo de error 
from sklearn.metrics import root_mean_squared_error
predictions = modelo.predict(X_train)
rmse = root_mean_squared_error(y_train, predictions)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 365.12674065193085

# %%
# Calculo de predicciones 
predicciones = modelo.predict(X_pred_procesado)
predicciones
# Out:
# array([ 939.45038343, 1015.82721655,  309.05363512, 2251.90019272,
#        1452.04230642,  670.11837112, 2020.26999137,  699.94736695,
#        1497.82887389,  630.87294962, 1058.78158608, 1955.60270933,
#         480.89677073,  633.64480509, 1274.9425974 , 2120.76240736,
#          77.68369333, 1045.1595141 , 1910.2240856 ,  462.31458103,
#        1567.22734537, 1323.77620136, 1912.47836074,  665.8815392 ,
#         638.83228239,  704.00774998,  830.41866144, 1873.75051957,
#        1381.25834612,  798.71165419, 1793.41367613, 1260.50751254,
#         227.40631243, 2127.92901849, 1113.11951325,  179.3052241 ,
#        1274.9425974 , 1721.67995338,  842.70319208, 1297.61805552,
#        1948.08529216, 1854.89136183, 1685.02666196, 1109.14013935,
#        1254.22583119,  788.91137555,  626.30996378, 3920.67540723,
#        1044.03969515, 1106.80243358,  515.812986  ,  712.19134525,
#         612.13476473,  330.86179291, 1003.73118854,  320.65080218,
#        1140.04883878,  917.54713795, 1841.72886513, 1107.17242124,
#         734.10284312,  660.25249424,  741.3063536 ,  400.93422591,
#         599.1640802 , 1860.49796323,  398.20458497, 1146.20890435,
#        1259.49207553,  990.96459523,  319.        , 1960.36815445,
#         939.45038343,  610.391275  ,  408.76190682, 1932.67798005,
#        1166.62436363,  857.00723568, 1196.14188613, 1326.7270962 ,
#        1992.768719  ,  936.44107007, 1719.19768565,  483.67128393,
#         842.70319208, 1037.54620939, 1809.84833675, 1074.72647003,
#         137.73297138,  861.90423426, 1016.72300912,  804.48180193,
#        1724.56909967, 2195.96996279,  717.89935392, 1256.09587394,
#        1367.67386177,  961.77085661, 1837.02469873,  764.76990873,
#        1278.00171841,  556.76969415, 1856.65133734,  593.66764487,
#         666.81722408,  169.52766777, 1286.73015234, 1337.87619991,
#        1038.47092564,  808.52286578, 1469.56548887, 1207.77626574,
#         721.87291288, 1735.55251942, 1033.49332747,  532.01802503,
#        1889.61929404,  788.50922007, 1048.51155407,  904.74839442,
#        1993.03191456, 1066.21605773, 1742.29512489,  847.36605072,
#        1047.19935957, 1077.04712894, 1574.36803093,  699.23154016,
#         449.6332652 ,  841.22497106,  506.1282743 ,  612.57306211,
#         809.99628884, 1534.49376623, 1030.09822789,  713.781049  ,
#         935.27462233, 2007.45493343, 1011.81730866,  992.33622857,
#        1236.46500124, 1405.36730868,  621.4093093 ,  213.99805284,
#         674.54552908,  981.89020358, 1263.28604708,  971.74818836,
#         416.18220031,  633.80237997, 1180.28315291, 2671.69788273,
#        2136.53674645, 1215.48786052, 1330.70300972, 1948.41725572,
#        1491.2512929 , 2150.20686534,  502.22198327,  408.01556705,
#        1377.98162295, 1163.47696258, 1048.50487499, 1515.12223949,
#         486.10683123, 1897.43149866,  959.94530262, 1359.18294641,
#        1151.83639373,  842.48264179, 1824.37654886, 1039.76488791,
#        1827.47517932, 1152.57040655, 1501.89195712, 2740.40943598,
#        1758.82333677, 1164.47418038,  988.2521786 , 1232.0198033 ,
#        1832.53771572, 1261.89476914,  994.29422622, 1011.18295202,
#        1742.19854124, 1281.24573261, 2598.30192083, 1471.54161874,
#        1297.41397414, 1331.20029574, 1814.22095457, 1977.30726027,
#        1367.15970483, 1630.31631292, 3187.93911089, 1254.55359182,
#         826.6054663 ,  948.20672524, 1209.94087441,  981.06808158,
#        2002.03320835, 1050.39662186,  726.88824061, 1925.90862304,
#        1061.29807182, 1100.94520109, 1633.08070757,  225.60969893,
#        1610.15028465,  553.16038457, 1030.05409167, 1155.45476123,
#        3305.18614068, 1442.03345915,  572.0806858 ,  809.00413926,
#        2092.63965013,  684.14851205,  689.72683625, 1028.87834701,
#         507.93704977, 1852.77426983, 1578.45747653, 1300.17606529,
#         723.60405076, 1081.08630688, 1444.21695542,  821.26889841,
#        2015.77847306, 2104.55982632, 1228.19571633,  728.51633571,
#        1303.67345113,  768.49139805, 1779.75488684, 1986.9284771 ,
#        1170.9015447 , 1105.79391041,  414.94435923,  316.3542626 ,
#        1333.77118592, 1189.04397258,  735.87561617, 1378.19279805,
#        2070.82116959,  259.8370338 ,  724.07858307, 1100.94520109,
#        1098.26987052, 1556.03510353,  652.15330173, 1364.24251215,
#         556.49103095,  862.82852295,  553.84390278, 1032.82860488,
#        1021.14074352,  828.04840817, 1100.03983785, 1871.00187461,
#        1728.69092731,  686.61036974,  811.9401311 , 1607.05645554,
#        1049.61864367, 1007.09890206,  810.89248469,  827.60484805,
#        1965.46922928,  562.06935515,  835.07740695,  675.42007812,
#        1513.04572326,  595.80161535, 1358.45761648, 1447.97609708,
#         888.38499524,  724.07858307, 1922.74938572,  466.8945202 ,
#        3019.30362608,  214.88674552, 1851.91440147, 2146.72492143,
#        1272.47794384,  594.31764241, 1203.09792966, 1319.82090003,
#         968.72271412,  572.43919613,  764.76990873,  732.38723871,
#         301.86401851,  312.53948444, 1048.29087469,  561.52235571,
#         282.57505365, 1260.50751254,  584.05899235, 1059.30419687,
#        2473.97705888, 1046.70117093, 1898.19141014,  233.62802306,
#        1050.35085207,  460.12229815,  929.53311872, 1487.76239928,
#        1274.9425974 ,  587.62018087, 1794.84426881,  912.80516131,
#        1231.52546531, 1011.27186004,  995.59329717,  769.13412569,
#        1230.1969347 ,  450.57559455, 1130.47267734, 1457.92324061,
#         143.22436314, 1134.36786901,  779.6020102 ,  793.94509541,
#        1008.12177461,  696.46067213, 1364.93915199,  988.2521786 ,
#         775.80776029, 1626.2046785 , 1582.79666319, 1368.47327386,
#         426.832601  ,  978.78297843, 2110.06322962,  919.46415862,
#         546.82510698,  857.74246444, 1826.74356878, 1074.94449166,
#         695.1233921 ,  833.36226885,  539.88882395,  784.7265465 ,
#         524.28704799, 1935.8399036 , 1139.98620284,  587.62018087,
#        1790.27000275,  949.64105499, 1081.80305484, 1336.61018741,
#        1079.80596113, 1067.93048879,  881.29744772,  287.01279209,
#        1261.89476914, 1827.47517932, 1807.07933289,  805.62523758,
#         410.72415188, 1069.38091259, 1220.23224835, 1061.29807182,
#         731.15243336, 1045.32948881, 1481.80366477,  774.04896245,
#        1411.85460562,  863.66623299, 1286.73015234, 1085.33848974,
#        1832.9903497 , 1092.25655843, 1351.77072831,  824.21078735,
#         375.71060513, 1221.89437949, 1079.58441718, 2002.03320835,
#        2392.12891919, 1038.57605712,  750.03511139,  574.94353617,
#         714.69745514, 1762.61989872, 1072.29068443, 1224.03394651,
#         942.08801987, 1378.19279805, 1037.57821921])

# %%
#caega de datos de sample
sample = pd.read_csv("/Users/isaromobru/Desktop/DS102024_/ordenadores/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_euros
# 0        539          650
# 1        327          650
# 2        563          650
# 3         13          650
# 4        935          500

# %%
sample.shape
# Out:
# (391, 2)

# %%
sample
# Out:
#      laptop_ID  Price_euros
# 0          539          650
# 1          327          650
# 2          563          650
# 3           13          650
# 4          935          500
# ..         ...          ...
# 386        742          650
# 387        660          650
# 388        983          650
# 389       1137          500
# 390        556          500
#
# [391 rows x 2 columns]

# %%
submission = pd.DataFrame({"laptop_ID": sample['laptop_ID'], "Price_euros": predicciones})

# %%
submission.head()
# Out:
#    laptop_ID  Price_euros
# 0        539   939.450383
# 1        327  1015.827217
# 2        563   309.053635
# 3         13  2251.900193
# 4        935  1452.042306

# %%
def chequeator(df_to_submit,version):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit['laptop_ID'].all() == sample['laptop_ID'].all():
                print("You're ready to submit!")
                submission.to_csv(f"submission_{version}.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto de Clara: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `diamonds_test.csv`. Lloro.")

# %%
chequeator(submission,2)
# Out:
# You're ready to submit!
