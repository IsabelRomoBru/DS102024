# %% [markdown]
# # Análisis de datos de Titanic

# %% [markdown]
# # librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.datasets import load_iris

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Primera exploración

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic[titanic.duplicated(keep=False)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 28          1       3  female   NaN      0      0   7.8792        Q   Third
# 29          0       3    male   NaN      0      0   7.8958        S   Third
# 32          1       3  female   NaN      0      0   7.7500        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[titanic['age'].isna()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic[titanic['pclass'].isna()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
titanic[titanic['class'].isna()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
titanic[titanic['embark_town'].isna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
titanic[titanic['embark_town'].isna()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
titanic.drop(columns=['pclass'],inplace=True)
titanic.drop(columns=['embarked'],inplace=True)
titanic.drop(columns=['alive'],inplace=True)

# %%
titanic[titanic['age'].isna()]
# Out:
#      survived     sex  age  sibsp  parch     fare   class    who  adult_male  \
# 5           0    male  NaN      0      0   8.4583   Third    man        True
# 17          1    male  NaN      0      0  13.0000  Second    man        True
# 19          1  female  NaN      0      0   7.2250   Third  woman       False
# 26          0    male  NaN      0      0   7.2250   Third    man        True
# 28          1  female  NaN      0      0   7.8792   Third  woman       False
# ..        ...     ...  ...    ...    ...      ...     ...    ...         ...
# 859         0    male  NaN      0      0   7.2292   Third    man        True
# 863         0  female  NaN      8      2  69.5500   Third  woman       False
# 868         0    male  NaN      0      0   9.5000   Third    man        True
# 878         0    male  NaN      0      0   7.8958   Third    man        True
# 888         0  female  NaN      1      2  23.4500   Third  woman       False
#
#     deck  embark_town  alone
# ...

# %%
titanic[titanic['deck'].isna()]
# Out:
#      survived     sex   age  sibsp  parch     fare   class    who  adult_male  \
# 0           0    male  22.0      1      0   7.2500   Third    man        True
# 2           1  female  26.0      0      0   7.9250   Third  woman       False
# 4           0    male  35.0      0      0   8.0500   Third    man        True
# 5           0    male   NaN      0      0   8.4583   Third    man        True
# 7           0    male   2.0      3      1  21.0750   Third  child       False
# ..        ...     ...   ...    ...    ...      ...     ...    ...         ...
# 884         0    male  25.0      0      0   7.0500   Third    man        True
# 885         0  female  39.0      0      5  29.1250   Third  woman       False
# 886         0    male  27.0      0      0  13.0000  Second    man        True
# 888         0  female   NaN      1      2  23.4500   Third  woman       False
# 890         0    male  32.0      0      0   7.7500   Third    man        True
#
#     deck  embark_town  alone
# ...

# %%
titanic.drop(columns=['deck'],inplace=True)

# %%
titanic[titanic['embark_town'].isna()]
# Out:
#      survived     sex   age  sibsp  parch  fare  class    who  adult_male  \
# 61          1  female  38.0      0      0  80.0  First  woman       False
# 829         1  female  62.0      0      0  80.0  First  woman       False
#
#     embark_town  alone
# 61          NaN   True
# 829         NaN   True

# %%
#estadisticas descriptivas
print(df[['age']])

# %%
titanic['embark_town'] = np.where(titanic['embark_town'].isna(), titanic['embark_town'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 titanic['embark_town'] = np.where(titanic['embark_town'].isna(), mode_value, titanic['embark_town'])
#
# NameError: name 'mode_value' is not defined

# %%
hacer boxplot

# %% [markdown]
# al tener outliers lo mejor es quedarse con la mediana
# si es normal se utiliza la media

# %% [markdown]
# hacer distribucion de las variables, con todas las categoricas

# %% [markdown]
# matriz de correlacion con las variabales
# tabla de contigencia
# el chi cuadrado confirma la relacion entre las variables
# anova: muy cercano a 0 esto confirma que  hay diferencia entre las medianas
