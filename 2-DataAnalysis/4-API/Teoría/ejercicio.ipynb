# %%
import hashlib
import requests
import datetime
import pandas as pd

# %%
def hash_params(timestamp,priv_key,pub_key):
    """ Marvel API requires server side API calls to include
    md5 hash of timestamp + public key + private key """

    hash_md5 = hashlib.md5()
    hash_md5.update(f'{timestamp}{priv_key}{pub_key}'.encode('utf-8'))
    hashed_params = hash_md5.hexdigest()

    return hashed_params

# %%
timestamp = datetime.datetime.now().strftime('%Y-%m-%d%H:%M:%S')

pub_key = 'd52fcc5393e32752bfabc8430969977b'
priv_key = 'd360e7ba36653ebbb67e252c05269985d3706b75'

params = {'ts': timestamp, 
        'apikey': pub_key, 
        'hash': hash_params(timestamp,priv_key,pub_key),
        'nameStartsWith':"I",
        # 'offset':,
        # 'limit': 100
        #'name':'hulk' 
        }

url = 'http://gateway.marvel.com/v1/public/characters'

res = requests.get(url,params=params)

# %%
data = res.json()
marvellist = [
    {
        "name": marvel["name"],
        "id": marvel["id"],
        "pictureurl": marvel["thumbnail"]["path"] + "." + marvel["thumbnail"]["extension"]
    }
    for marvel in data["data"]["results"]
]
marveldf=pd.DataFrame(marvellist)
marveldf
# Out:
#                                            name       id  \
# 0                                        Iceman  1009362
# 1                             Iceman (Ultimate)  1010933
# 2            Iceman (X-Men: Battle of the Atom)  1017475
# 3                                        Ikaris  1011077
# 4                                    Illuminati  1010758
# 5                               Ilyana Rasputin  1009529
# 6                                      Immortus  1012923
# 7                                           Imp  1011273
# 8                                    Imperfects  1011089
# 9                                Imperial Guard  1009363
# 10                               Impossible Man  1009364
# 11                                 In-Betweener  1011063
# 12                                      Inertia  1011064
# 13                              Infant Terrible  1011146
# 14                                     Inhumans  1009365
# 15                                          Ink  1011293
# 16                                     Invaders  1011024
# 17                              Invisible Woman  1009366
# 18  Invisible Woman (Marvel: Avengers Alliance)  1017301
# 19                   Invisible Woman (Ultimate)  1010934
#
#                                            pictureurl
# 0   http://i.annihil.us/u/prod/marvel/i/mg/1/d0/52...
# 1   http://i.annihil.us/u/prod/marvel/i/mg/3/70/53...
# 2   http://i.annihil.us/u/prod/marvel/i/mg/9/70/52...
# 3   http://i.annihil.us/u/prod/marvel/i/mg/9/50/4c...
# 4   http://i.annihil.us/u/prod/marvel/i/mg/5/70/52...
# 5   http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...
# 6   http://i.annihil.us/u/prod/marvel/i/mg/1/a0/4c...
# 7   http://i.annihil.us/u/prod/marvel/i/mg/9/30/4c...
# 8   http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...
# 9   http://i.annihil.us/u/prod/marvel/i/mg/6/30/53...
# 10  http://i.annihil.us/u/prod/marvel/i/mg/8/90/4c...
# 11  http://i.annihil.us/u/prod/marvel/i/mg/9/60/4c...
# 12  http://i.annihil.us/u/prod/marvel/i/mg/b/60/4c...
# 13  http://i.annihil.us/u/prod/marvel/i/mg/2/f0/4c...
# 14  http://i.annihil.us/u/prod/marvel/i/mg/5/a0/52...
# 15  http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...
# 16  http://i.annihil.us/u/prod/marvel/i/mg/9/60/53...
# 17  http://i.annihil.us/u/prod/marvel/i/mg/6/a0/52...
# 18  http://i.annihil.us/u/prod/marvel/i/mg/6/80/52...
# 19  http://i.annihil.us/u/prod/marvel/i/mg/5/b0/4c...

# %%
 from IPython.display import HTML
url = 'http://gateway.marvel.com/v1/public/characters'
# Solicitar datos a la API
response = requests.get(url, params=params)
if response.status_code == 200:
    data = response.json()
    results = data.get('data', {}).get('results', [])
    marvel = pd.DataFrame([{
        'id': i['id'],
        'name': i['name'],
        'picture': f"<img src='{i['thumbnail']['path']}.{i['thumbnail']['extension']}' width='100' />"
    } for i in results])
    # Renderizar como HTML con imágenes
    def render_mixed_dataframe(dataframe):
        return HTML(dataframe.to_html(escape=False))
    display(render_mixed_dataframe(marvel))
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>picture</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1009362</td>
#       <td>Iceman</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/1/d0/52696c836898c.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1010933</td>
#       <td>Iceman (Ultimate)</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/3/70/53176e6436aa6.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1017475</td>
#       <td>Iceman (X-Men: Battle of the Atom)</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/9/70/52d72ac3c45f9.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1011077</td>
#       <td>Ikaris</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/9/50/4c0030d8df78e.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1010758</td>
#       <td>Illuminati</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/5/70/526033bb40a5e.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1009529</td>
#       <td>Ilyana Rasputin</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1012923</td>
#       <td>Immortus</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/1/a0/4ce5aa10cfeb5.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1011273</td>
#       <td>Imp</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/9/30/4c002eee45d85.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1011089</td>
#       <td>Imperfects</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1009363</td>
#       <td>Imperial Guard</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/6/30/539a0286b06bf.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1009364</td>
#       <td>Impossible Man</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/8/90/4c003eb8e1d23.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1011063</td>
#       <td>In-Betweener</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/9/60/4c0030f999ecb.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1011064</td>
#       <td>Inertia</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/b/60/4c0030f6eab3d.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1011146</td>
#       <td>Infant Terrible</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/2/f0/4c002f7854e02.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1009365</td>
#       <td>Inhumans</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/5/a0/526033a73dca3.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1011293</td>
#       <td>Ink</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1011024</td>
#       <td>Invaders</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/9/60/539b3c2fca079.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1009366</td>
#       <td>Invisible Woman</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/6/a0/52695b9cd40b6.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1017301</td>
#       <td>Invisible Woman (Marvel: Avengers Alliance)</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/6/80/5239b5c4cb782.jpg' width='100' /></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1010934</td>
#       <td>Invisible Woman (Ultimate)</td>
#       <td><img src='http://i.annihil.us/u/prod/marvel/i/mg/5/b0/4c00342d26fc5.jpg' width='100' /></td>
#     </tr>
#   </tbody>
# </table>
