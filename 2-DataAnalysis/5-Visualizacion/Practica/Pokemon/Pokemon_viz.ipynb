# %% [markdown]
# # Pokemon **

# %% [markdown]
# ### Step 1. Importa las librerías necesarias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %% [markdown]
# ### Step 2. Activa matplotlib de forma estática

# %%
plt.ioff()

# %% [markdown]
# ### Step 3. Lee 'pokemon.csv' de esta [url](https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv), lee la primera columna del csv como índice del DataFrame

# %%
url='https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv'
df=pd.read_csv(url)
df.set_index('#', inplace=True)

# %% [markdown]
# ### Step 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Step 5. Haz un scatter plot con `lmplot()`, que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado `data`

# %%
p=sns.lmplot(data=df,x='Attack', y='Defense',markers=".")
ax = plt.gca()  
ax.set_xticks([0, 20, 40, 60,80,100,120,140])  
ax.set_xticklabels(["0", "20", "40", "60","80","100","120","140"])  
ax.set_yticks([0,25,50,75,100,125,150,175])  
ax.set_yticklabels(["0", "25", "50", "75","100", "125","150", "175"])
ax.grid(False)

# %% [markdown]
# ### Step 6. No queremos ver la línea recta de la regresión lineal.
# Prueba a añadir fit_reg a falso

# %%
p=sns.lmplot(data=df,x='Attack', y='Defense',markers=".",  scatter_kws={"color": "blue"},fit_reg=False,)
ax = plt.gca()  
ax.set_xticks([0, 20, 40, 60,80,100,120,140])  
ax.set_xticklabels(["0", "20", "40", "60","80","100","120","140"])  
ax.set_yticks([0,25,50,75,100,125,150,175])  
ax.set_yticklabels(["0", "25", "50", "75","100", "125","150", "175"])
ax.grid(False)

plt.show()

# %% [markdown]
# ### Step 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el `hue` sea el Stage

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
sns.lmplot(data=df,x='Attack',y='Defense',hue='Generation')
plt.show;

# %% [markdown]
# ### Step 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(data=df,x='Attack',y='Defense',hue='Generation')
plt.xlim(20, 100)

plt.show;

# %% [markdown]
# ### Step 9. Dibuja un diagrama de cajas con el dataframe

# %%
sns.boxplot(data=data,x='final_sec')

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dff=df.drop(columns='Generation')

# %%
sns.boxplot(data=dff);

# %% [markdown]
# ### Step 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed'],
#       dtype='object')

# %%
dff=df.drop(columns='Legendary')
df2=dff.drop(columns='Total')
df2=df2.drop(columns='Generation')

# %%
sns.boxplot(data=df2);

# %% [markdown]
# ### Step 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# ### Step 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
df3=df[df['Type 1'].isin(['Grass', 'Fire', 'Water'])]

# %% [markdown]
# ### Step 13. Usa un estilo 'whitegrid'

# %%
sns.set_style('whitegrid')

# %% [markdown]
# ### Step 14. Pinta diagramas de violín con el DataFrame

# %%
sns.violinplot(data=df3, x="Type 1", y="Attack", hue='Type 1',
               palette=["blue", "orange","green"], legend=False)
plt.show();

# %% [markdown]
# ### Step 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colores = ['#78C850', '#F08030', '#6890F0']

# %% [markdown]
# ### Step 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(data=df3, x="Type 1", y="Attack", hue='Type 1',
               palette=colores, legend=False)
plt.show();

# %%
sns.violinplot(data=df3, x="Type 1", y="Attack", hue='Type 1',
               palette=["#78C850", "#F08030","#6890F0"], legend=False)
plt.show();

# %% [markdown]
# ### Step 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# - Para ver esto, usamos el swarmplot.
# - Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.swarmplot(data=df3, x="Type 1", y="Attack", hue="Type 1", palette="Set2")
plt.show();

# %% [markdown]
# ### Step 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9

# %%
df3.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df3, x='Type 1', y='Attack', inner=None, alpha=0.9,palette=["#78C850", "#F08030","#6890F0"])
sns.swarmplot(data=df3, x='Type 1', y='Attack', color='Green', alpha=0.8)


plt.show();
# Out:
# /var/folders/pq/mppvlq_j3_7b5gpr_bpc5khm0000gn/T/ipykernel_55570/3264458256.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df3, x='Type 1', y='Attack', inner=None, alpha=0.9,palette=["#78C850", "#F08030","#6890F0"])

# %% [markdown]
# ### Step 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
#  Dado un DataFrame, [melt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html) recibe varios parámetros:
#  * qué columnas del DataFrame se quedan igual
#  * qué nombres de columnas del dataframe pasan a ser una columna nueva
#  * cómo queremos llamar esas nuevas columnas
#
# Primero recuerda el Dataframe `df_grass_fire_water` con las primeras 5 filas

# %%
df3.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Step 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
#
# Escribimos `df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')`

# %%
df4= df3.melt(id_vars=['Name', 'Type 1'], value_vars=['Legendary','Generation'], var_name='New Column')

# %% [markdown]
# ### Step 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
print(df4.columns)
# Out:
# Index(['Name', 'Type 1', 'New Column', 'value'], dtype='object')

# %%
sns.swarmplot(data=df4, x='New Column', y='value', hue='Type 1', palette="Set2")
# Out:
# /Users/isaromobru/Desktop/DS102024_/.venv/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 73.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='New Column', ylabel='value'>
# /Users/isaromobru/Desktop/DS102024_/.venv/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 83.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/isaromobru/Desktop/DS102024_/.venv/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 34.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Step 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# Usando plt:
#   - fija el límite del eje Y entre 0 y 200
#   - fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %% [markdown]
# ### Step 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
#
# Las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
df.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = df.corr()
print(correlation_matrix)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Matriz de Correlación")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[165], line 2
#       1 numeric_df = df.select_dtypes(include=['number'])
# ----> 2 correlation_matrix = df.corr()
#       3 print(correlation_matrix)
#       5 plt.figure(figsize=(10, 8))
#
# File ~/Desktop/DS102024_/.venv/lib/python3.13/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Desktop/DS102024_/.venv/lib/python3.13/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/Desktop/DS102024_/.venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/Desktop/DS102024_/.venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Bulbasaur'

# %% [markdown]
# ### Step 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.histplot(df['Defense'],kde=True);

# %% [markdown]
# ### Step 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot y plt.xticks para girar las etiquetas

# %%
sns.countplot(data=df, x='Type 1',  palette='viridis')
plt.tight_layout()
plt.xticks(rotation=60);
# Out:
# /var/folders/pq/mppvlq_j3_7b5gpr_bpc5khm0000gn/T/ipykernel_55570/1523613193.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Type 1',  palette='viridis')

# %% [markdown]
# ### Step 26. Usa catplot con el DataFrame original.
# Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendariosy divide los colores según el Type 2

# %% [markdown]
# ### Step 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.

# %%
sns.kdeplot(data=df,x='Attack',y='Defense', color='blue')
plt.show();

# %% [markdown]
# ### Step 29. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original

# %%
sns.jointplot( df,x="Attack", y="Defense",color='skyblue')
